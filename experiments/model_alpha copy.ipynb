# %%
import datetime
import os
import sys
import time

from torch.optim import Optimizer
from torch.utils.data import DataLoader

from inference import infer, evaluate
from metrics import Metrics

# Hack for module imports
module_path = os.path.abspath(os.path.join('../data'))
if module_path not in sys.path:
    sys.path.append(module_path)

from loaders import FlatsDatasetLoader

import numpy as np
import torch
import torch.nn as nn
from tqdm import tqdm

import plots

# %%
device = torch.device('mps' if torch.backends.mps.is_available() else 'cuda' if torch.cuda.is_available() else 'cpu')
print(f'Will operate on device {device}')
# Out:
# Will operate on device mps

# %%
image_size = 256

data_path = '/Users/adamwojdyla/Documents/Studia/Magisterskie/AITechFlats/Scrapper/ImageScrapper/ImageScrapper/Images/Houzz'

data_loader = FlatsDatasetLoader(
    images_dir=data_path,
    resize_to=image_size,
    device=device,
    batch_size=30
)

# %%
full = data_loader.load_v2(verbose=True)
train_loader = data_loader.get_train_loader()
test_loader = data_loader.get_test_loader()
classes_count = data_loader.get_classes_count()
# Out:
# Loading dataset from files...
# Done. Creating PyTorch datasets...
# Done.

# %%
print(data_loader)
# Out:
# {
#   "Full dataset count: ": 12848,
#   "Train dataset count: ": 8993,
#   "Test dataset count: ": 3855,
#   "Classes count: ": 9,
#   "Label names: ": {
#     "0": "ArtDeco",
#     "1": "Classic",
#     "2": "Glamour",
#     "3": "Industrial",
#     "4": "Minimalistic",
#     "5": "Modern",
#     "6": "Rustic",
#     "7": "Scandinavian",
#     "8": "Vintage"
#   }
# }

# %%
from typing import Union

def train(
        model: nn.Module,
        train_data: DataLoader,
        test_data: DataLoader,
        optimizer_fn: Optimizer,
        loss_fn,
        epochs: int
) -> Union[Metrics, Metrics]:
    model.train()
    test_metrics = Metrics()
    train_metrics = Metrics()
    epoch=0
    for _ in tqdm(range(epochs), total=epochs):
        epoch+=1
        train_outs, train_losses = np.array([]), []
        ys = np.array([])

        for batch_idx, data in enumerate(train_data):
            print(f'Epoch: {epoch}, Batch_idx: {batch_idx}, Batch_size: {len(data[0])}')
            optimizer_fn.zero_grad()            
            output, loss = infer(data, model, loss_fn, device)
            ys = np.concatenate((ys, data[1].data.numpy()))
            train_outs = np.concatenate(
                (train_outs, torch.nn.functional.softmax(output, dim=1).cpu().data.numpy().argmax(axis=1))
            )
            loss.backward()
            train_losses.append(loss.item())
            optimizer_fn.step()
            
            if batch_idx % 100 == 0:
                print('Training set [{}/{} ({:.0f}%)] Loss: {:.6f}'.format(
                    batch_idx * len(data[0]), 
                    len(train_loader.dataset),
                    100. * batch_idx / len(train_loader),
                    loss.item())
                )
        train_metrics.add_new(train_outs, ys, train_losses)
        test_trues, test_preds, test_losses = evaluate(model, test_data, loss_fn, device)
        test_metrics.add_new(test_preds, test_trues, test_losses)
        print(f'Metrics after epoch: {epoch}: ', end='')
        print(test_metrics)
    
    return test_metrics, train_metrics

# %%
def conduct_experiment(title, model, n_epochs, optimizer):
    criterion = nn.CrossEntropyLoss()

    start = time.time()
    test_metrics, train_metrics = train(model, train_loader, test_loader, optimizer, criterion, n_epochs)
    end = time.time()
    model_directory = os.path.join('models', title)
    path = os.path.join(model_directory, f'{datetime.datetime.now().strftime("%y-%b-%d-%H-%M")}.pt')
    try:
        os.mkdir(model_directory)
    except FileExistsError:
        pass
    torch.save(model, path)
    print(f'Model saved in {path}')
    plots.plot_metrics(title, test_metrics, train_metrics, n_epochs, end - start, image_size, device)
    _, preds, _ = evaluate(model, test_loader, criterion, device)
    labels = data_loader.get_label_names()
    plots.show_missclassified(test_loader.dataset, preds, labels)

    return test_metrics, train_metrics

# %%
resnet_model = torch.hub.load(
    'pytorch/vision:v0.10.0',
    'resnet18',
    num_classes=data_loader.get_classes_count()
).to(device)
# Out:
# Using cache found in /Users/adamwojdyla/.cache/torch/hub/pytorch_vision_v0.10.0

# %%
test_metrics, train_metrics = conduct_experiment("ResNet18", resnet_model, 5, torch.optim.Adam(resnet_model.parameters()))
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# Epoch: 1, Batch_idx: 0, Batch_size: 30
# Training set [0/8993 (0%)] Loss: 2.389553
# Epoch: 1, Batch_idx: 1, Batch_size: 30
# Epoch: 1, Batch_idx: 2, Batch_size: 30
# Epoch: 1, Batch_idx: 3, Batch_size: 30
# Epoch: 1, Batch_idx: 4, Batch_size: 30
# Epoch: 1, Batch_idx: 5, Batch_size: 30
# Epoch: 1, Batch_idx: 6, Batch_size: 30
# Epoch: 1, Batch_idx: 7, Batch_size: 30
# Epoch: 1, Batch_idx: 8, Batch_size: 30
# Epoch: 1, Batch_idx: 9, Batch_size: 30
# Epoch: 1, Batch_idx: 10, Batch_size: 30
# Epoch: 1, Batch_idx: 11, Batch_size: 30
# Epoch: 1, Batch_idx: 12, Batch_size: 30
# Epoch: 1, Batch_idx: 13, Batch_size: 30
# Epoch: 1, Batch_idx: 14, Batch_size: 30
# Epoch: 1, Batch_idx: 15, Batch_size: 30
# Epoch: 1, Batch_idx: 16, Batch_size: 30
# Epoch: 1, Batch_idx: 17, Batch_size: 30
# Epoch: 1, Batch_idx: 18, Batch_size: 30
# Epoch: 1, Batch_idx: 19, Batch_size: 30
# Epoch: 1, Batch_idx: 20, Batch_size: 30
# Epoch: 1, Batch_idx: 21, Batch_size: 30
# Epoch: 1, Batch_idx: 22, Batch_size: 30
# Epoch: 1, Batch_idx: 23, Batch_size: 30
# Epoch: 1, Batch_idx: 24, Batch_size: 30
# Epoch: 1, Batch_idx: 25, Batch_size: 30
# Epoch: 1, Batch_idx: 26, Batch_size: 30
# Epoch: 1, Batch_idx: 27, Batch_size: 30
# Epoch: 1, Batch_idx: 28, Batch_size: 30
# Epoch: 1, Batch_idx: 29, Batch_size: 30
# Epoch: 1, Batch_idx: 30, Batch_size: 30
# Epoch: 1, Batch_idx: 31, Batch_size: 30
# Epoch: 1, Batch_idx: 32, Batch_size: 30
# Epoch: 1, Batch_idx: 33, Batch_size: 30
# Epoch: 1, Batch_idx: 34, Batch_size: 30
# Epoch: 1, Batch_idx: 35, Batch_size: 30
# Epoch: 1, Batch_idx: 36, Batch_size: 30
# Epoch: 1, Batch_idx: 37, Batch_size: 30
# Epoch: 1, Batch_idx: 38, Batch_size: 30
# Epoch: 1, Batch_idx: 39, Batch_size: 30
# Epoch: 1, Batch_idx: 40, Batch_size: 30
# Epoch: 1, Batch_idx: 41, Batch_size: 30
# Epoch: 1, Batch_idx: 42, Batch_size: 30
# Epoch: 1, Batch_idx: 43, Batch_size: 30
# Epoch: 1, Batch_idx: 44, Batch_size: 30
# Epoch: 1, Batch_idx: 45, Batch_size: 30
# Epoch: 1, Batch_idx: 46, Batch_size: 30
# Epoch: 1, Batch_idx: 47, Batch_size: 30
# Epoch: 1, Batch_idx: 48, Batch_size: 30
# Epoch: 1, Batch_idx: 49, Batch_size: 30
# Epoch: 1, Batch_idx: 50, Batch_size: 30
# Epoch: 1, Batch_idx: 51, Batch_size: 30
# Epoch: 1, Batch_idx: 52, Batch_size: 30
# Epoch: 1, Batch_idx: 53, Batch_size: 30
# Epoch: 1, Batch_idx: 54, Batch_size: 30
# Epoch: 1, Batch_idx: 55, Batch_size: 30
# Epoch: 1, Batch_idx: 56, Batch_size: 30
# Epoch: 1, Batch_idx: 57, Batch_size: 30
# Epoch: 1, Batch_idx: 58, Batch_size: 30
# Epoch: 1, Batch_idx: 59, Batch_size: 30
# Epoch: 1, Batch_idx: 60, Batch_size: 30
# Epoch: 1, Batch_idx: 61, Batch_size: 30
# Epoch: 1, Batch_idx: 62, Batch_size: 30
# Epoch: 1, Batch_idx: 63, Batch_size: 30
# Epoch: 1, Batch_idx: 64, Batch_size: 30
# Epoch: 1, Batch_idx: 65, Batch_size: 30
# Epoch: 1, Batch_idx: 66, Batch_size: 30
# Epoch: 1, Batch_idx: 67, Batch_size: 30
# Epoch: 1, Batch_idx: 68, Batch_size: 30
# Epoch: 1, Batch_idx: 69, Batch_size: 30
# Epoch: 1, Batch_idx: 70, Batch_size: 30
# Epoch: 1, Batch_idx: 71, Batch_size: 30
# Epoch: 1, Batch_idx: 72, Batch_size: 30
# Epoch: 1, Batch_idx: 73, Batch_size: 30
# Epoch: 1, Batch_idx: 74, Batch_size: 30
# Epoch: 1, Batch_idx: 75, Batch_size: 30
# Epoch: 1, Batch_idx: 76, Batch_size: 30
# Epoch: 1, Batch_idx: 77, Batch_size: 30
# Epoch: 1, Batch_idx: 78, Batch_size: 30
# Epoch: 1, Batch_idx: 79, Batch_size: 30
# Epoch: 1, Batch_idx: 80, Batch_size: 30
# Epoch: 1, Batch_idx: 81, Batch_size: 30
# Epoch: 1, Batch_idx: 82, Batch_size: 30
# Epoch: 1, Batch_idx: 83, Batch_size: 30
# Epoch: 1, Batch_idx: 84, Batch_size: 30
# Epoch: 1, Batch_idx: 85, Batch_size: 30
# Epoch: 1, Batch_idx: 86, Batch_size: 30
# Epoch: 1, Batch_idx: 87, Batch_size: 30
# Epoch: 1, Batch_idx: 88, Batch_size: 30
# Epoch: 1, Batch_idx: 89, Batch_size: 30
# Epoch: 1, Batch_idx: 90, Batch_size: 30
# Epoch: 1, Batch_idx: 91, Batch_size: 30
# Epoch: 1, Batch_idx: 92, Batch_size: 30
# Epoch: 1, Batch_idx: 93, Batch_size: 30
# Epoch: 1, Batch_idx: 94, Batch_size: 30
# Epoch: 1, Batch_idx: 95, Batch_size: 30
# Epoch: 1, Batch_idx: 96, Batch_size: 30
# Epoch: 1, Batch_idx: 97, Batch_size: 30
# Epoch: 1, Batch_idx: 98, Batch_size: 30
# Epoch: 1, Batch_idx: 99, Batch_size: 30
# Epoch: 1, Batch_idx: 100, Batch_size: 30
# Training set [3000/8993 (33%)] Loss: 2.067798
# Epoch: 1, Batch_idx: 101, Batch_size: 30
# Epoch: 1, Batch_idx: 102, Batch_size: 30
# Epoch: 1, Batch_idx: 103, Batch_size: 30
# Epoch: 1, Batch_idx: 104, Batch_size: 30
# Epoch: 1, Batch_idx: 105, Batch_size: 30
# Epoch: 1, Batch_idx: 106, Batch_size: 30
# Epoch: 1, Batch_idx: 107, Batch_size: 30
# Epoch: 1, Batch_idx: 108, Batch_size: 30
# Epoch: 1, Batch_idx: 109, Batch_size: 30
# Epoch: 1, Batch_idx: 110, Batch_size: 30
# Epoch: 1, Batch_idx: 111, Batch_size: 30
# Epoch: 1, Batch_idx: 112, Batch_size: 30
# Epoch: 1, Batch_idx: 113, Batch_size: 30
# Epoch: 1, Batch_idx: 114, Batch_size: 30
# Epoch: 1, Batch_idx: 115, Batch_size: 30
# Epoch: 1, Batch_idx: 116, Batch_size: 30
# Epoch: 1, Batch_idx: 117, Batch_size: 30
# Epoch: 1, Batch_idx: 118, Batch_size: 30
# Epoch: 1, Batch_idx: 119, Batch_size: 30
# Epoch: 1, Batch_idx: 120, Batch_size: 30
# Epoch: 1, Batch_idx: 121, Batch_size: 30
# Epoch: 1, Batch_idx: 122, Batch_size: 30
# Epoch: 1, Batch_idx: 123, Batch_size: 30
# Epoch: 1, Batch_idx: 124, Batch_size: 30
# Epoch: 1, Batch_idx: 125, Batch_size: 30
# Epoch: 1, Batch_idx: 126, Batch_size: 30
# Epoch: 1, Batch_idx: 127, Batch_size: 30
# Epoch: 1, Batch_idx: 128, Batch_size: 30
# Epoch: 1, Batch_idx: 129, Batch_size: 30
# Epoch: 1, Batch_idx: 130, Batch_size: 30
# Epoch: 1, Batch_idx: 131, Batch_size: 30
# Epoch: 1, Batch_idx: 132, Batch_size: 30
# Epoch: 1, Batch_idx: 133, Batch_size: 30
# Epoch: 1, Batch_idx: 134, Batch_size: 30
# Epoch: 1, Batch_idx: 135, Batch_size: 30
# Epoch: 1, Batch_idx: 136, Batch_size: 30
# Epoch: 1, Batch_idx: 137, Batch_size: 30
# Epoch: 1, Batch_idx: 138, Batch_size: 30
# Epoch: 1, Batch_idx: 139, Batch_size: 30
# Epoch: 1, Batch_idx: 140, Batch_size: 30
# Epoch: 1, Batch_idx: 141, Batch_size: 30
# Epoch: 1, Batch_idx: 142, Batch_size: 30
# Epoch: 1, Batch_idx: 143, Batch_size: 30
# Epoch: 1, Batch_idx: 144, Batch_size: 30
# Epoch: 1, Batch_idx: 145, Batch_size: 30
# Epoch: 1, Batch_idx: 146, Batch_size: 30
# Epoch: 1, Batch_idx: 147, Batch_size: 30
# Epoch: 1, Batch_idx: 148, Batch_size: 30
# Epoch: 1, Batch_idx: 149, Batch_size: 30
# Epoch: 1, Batch_idx: 150, Batch_size: 30
# Epoch: 1, Batch_idx: 151, Batch_size: 30
# Epoch: 1, Batch_idx: 152, Batch_size: 30
# Epoch: 1, Batch_idx: 153, Batch_size: 30
# Epoch: 1, Batch_idx: 154, Batch_size: 30
# Epoch: 1, Batch_idx: 155, Batch_size: 30
# Epoch: 1, Batch_idx: 156, Batch_size: 30
# Epoch: 1, Batch_idx: 157, Batch_size: 30
# Epoch: 1, Batch_idx: 158, Batch_size: 30
# Epoch: 1, Batch_idx: 159, Batch_size: 30
# Epoch: 1, Batch_idx: 160, Batch_size: 30
# Epoch: 1, Batch_idx: 161, Batch_size: 30
# Epoch: 1, Batch_idx: 162, Batch_size: 30
# Epoch: 1, Batch_idx: 163, Batch_size: 30
# Epoch: 1, Batch_idx: 164, Batch_size: 30
# Epoch: 1, Batch_idx: 165, Batch_size: 30
# Epoch: 1, Batch_idx: 166, Batch_size: 30
# Epoch: 1, Batch_idx: 167, Batch_size: 30
# Epoch: 1, Batch_idx: 168, Batch_size: 30
# Epoch: 1, Batch_idx: 169, Batch_size: 30
# Epoch: 1, Batch_idx: 170, Batch_size: 30
# Epoch: 1, Batch_idx: 171, Batch_size: 30
# Epoch: 1, Batch_idx: 172, Batch_size: 30
# Epoch: 1, Batch_idx: 173, Batch_size: 30
# Epoch: 1, Batch_idx: 174, Batch_size: 30
# Epoch: 1, Batch_idx: 175, Batch_size: 30
# Epoch: 1, Batch_idx: 176, Batch_size: 30
# Epoch: 1, Batch_idx: 177, Batch_size: 30
# Epoch: 1, Batch_idx: 178, Batch_size: 30
# Epoch: 1, Batch_idx: 179, Batch_size: 30
# Epoch: 1, Batch_idx: 180, Batch_size: 30
# Epoch: 1, Batch_idx: 181, Batch_size: 30
# Epoch: 1, Batch_idx: 182, Batch_size: 30
# Epoch: 1, Batch_idx: 183, Batch_size: 30
# Epoch: 1, Batch_idx: 184, Batch_size: 30
# Epoch: 1, Batch_idx: 185, Batch_size: 30
# Epoch: 1, Batch_idx: 186, Batch_size: 30
# Epoch: 1, Batch_idx: 187, Batch_size: 30
# Epoch: 1, Batch_idx: 188, Batch_size: 30
# Epoch: 1, Batch_idx: 189, Batch_size: 30
# Epoch: 1, Batch_idx: 190, Batch_size: 30
# Epoch: 1, Batch_idx: 191, Batch_size: 30
# Epoch: 1, Batch_idx: 192, Batch_size: 30
# Epoch: 1, Batch_idx: 193, Batch_size: 30
# Epoch: 1, Batch_idx: 194, Batch_size: 30
# Epoch: 1, Batch_idx: 195, Batch_size: 30
# Epoch: 1, Batch_idx: 196, Batch_size: 30
# Epoch: 1, Batch_idx: 197, Batch_size: 30
# Epoch: 1, Batch_idx: 198, Batch_size: 30
# Epoch: 1, Batch_idx: 199, Batch_size: 30
# Epoch: 1, Batch_idx: 200, Batch_size: 30
# Training set [6000/8993 (67%)] Loss: 2.330993
# Epoch: 1, Batch_idx: 201, Batch_size: 30
# Epoch: 1, Batch_idx: 202, Batch_size: 30
# Epoch: 1, Batch_idx: 203, Batch_size: 30
# Epoch: 1, Batch_idx: 204, Batch_size: 30
# Epoch: 1, Batch_idx: 205, Batch_size: 30
# Epoch: 1, Batch_idx: 206, Batch_size: 30
# Epoch: 1, Batch_idx: 207, Batch_size: 30
# Epoch: 1, Batch_idx: 208, Batch_size: 30
# Epoch: 1, Batch_idx: 209, Batch_size: 30
# Epoch: 1, Batch_idx: 210, Batch_size: 30
# Epoch: 1, Batch_idx: 211, Batch_size: 30
# Epoch: 1, Batch_idx: 212, Batch_size: 30
# Epoch: 1, Batch_idx: 213, Batch_size: 30
# Epoch: 1, Batch_idx: 214, Batch_size: 30
# Epoch: 1, Batch_idx: 215, Batch_size: 30
# Epoch: 1, Batch_idx: 216, Batch_size: 30
# Epoch: 1, Batch_idx: 217, Batch_size: 30
# Epoch: 1, Batch_idx: 218, Batch_size: 30
# Epoch: 1, Batch_idx: 219, Batch_size: 30
# Epoch: 1, Batch_idx: 220, Batch_size: 30
# Epoch: 1, Batch_idx: 221, Batch_size: 30
# Epoch: 1, Batch_idx: 222, Batch_size: 30
# Epoch: 1, Batch_idx: 223, Batch_size: 30
# Epoch: 1, Batch_idx: 224, Batch_size: 30
# Epoch: 1, Batch_idx: 225, Batch_size: 30
# Epoch: 1, Batch_idx: 226, Batch_size: 30
# Epoch: 1, Batch_idx: 227, Batch_size: 30
# Epoch: 1, Batch_idx: 228, Batch_size: 30
# Epoch: 1, Batch_idx: 229, Batch_size: 30
# Epoch: 1, Batch_idx: 230, Batch_size: 30
# Epoch: 1, Batch_idx: 231, Batch_size: 30
# Epoch: 1, Batch_idx: 232, Batch_size: 30
# Epoch: 1, Batch_idx: 233, Batch_size: 30
# Epoch: 1, Batch_idx: 234, Batch_size: 30
# Epoch: 1, Batch_idx: 235, Batch_size: 30
# Epoch: 1, Batch_idx: 236, Batch_size: 30
# Epoch: 1, Batch_idx: 237, Batch_size: 30
# Epoch: 1, Batch_idx: 238, Batch_size: 30
# Epoch: 1, Batch_idx: 239, Batch_size: 30
# Epoch: 1, Batch_idx: 240, Batch_size: 30
# Epoch: 1, Batch_idx: 241, Batch_size: 30
# Epoch: 1, Batch_idx: 242, Batch_size: 30
# Epoch: 1, Batch_idx: 243, Batch_size: 30
# Epoch: 1, Batch_idx: 244, Batch_size: 30
# Epoch: 1, Batch_idx: 245, Batch_size: 30
# Epoch: 1, Batch_idx: 246, Batch_size: 30
# Epoch: 1, Batch_idx: 247, Batch_size: 30
# Epoch: 1, Batch_idx: 248, Batch_size: 30
# Epoch: 1, Batch_idx: 249, Batch_size: 30
# Epoch: 1, Batch_idx: 250, Batch_size: 30
# Epoch: 1, Batch_idx: 251, Batch_size: 30
# Epoch: 1, Batch_idx: 252, Batch_size: 30
# Epoch: 1, Batch_idx: 253, Batch_size: 30
# Epoch: 1, Batch_idx: 254, Batch_size: 30
# Epoch: 1, Batch_idx: 255, Batch_size: 30
# Epoch: 1, Batch_idx: 256, Batch_size: 30
# Epoch: 1, Batch_idx: 257, Batch_size: 30
# Epoch: 1, Batch_idx: 258, Batch_size: 30
# Epoch: 1, Batch_idx: 259, Batch_size: 30
# Epoch: 1, Batch_idx: 260, Batch_size: 30
# Epoch: 1, Batch_idx: 261, Batch_size: 30
# Epoch: 1, Batch_idx: 262, Batch_size: 30
# Epoch: 1, Batch_idx: 263, Batch_size: 30
# Epoch: 1, Batch_idx: 264, Batch_size: 30
# Epoch: 1, Batch_idx: 265, Batch_size: 30
# Epoch: 1, Batch_idx: 266, Batch_size: 30
# Epoch: 1, Batch_idx: 267, Batch_size: 30
# Epoch: 1, Batch_idx: 268, Batch_size: 30
# Epoch: 1, Batch_idx: 269, Batch_size: 30
# Epoch: 1, Batch_idx: 270, Batch_size: 30
# Epoch: 1, Batch_idx: 271, Batch_size: 30
# Epoch: 1, Batch_idx: 272, Batch_size: 30
# Epoch: 1, Batch_idx: 273, Batch_size: 30
# Epoch: 1, Batch_idx: 274, Batch_size: 30
# Epoch: 1, Batch_idx: 275, Batch_size: 30
# Epoch: 1, Batch_idx: 276, Batch_size: 30
# Epoch: 1, Batch_idx: 277, Batch_size: 30
# Epoch: 1, Batch_idx: 278, Batch_size: 30
# Epoch: 1, Batch_idx: 279, Batch_size: 30
# Epoch: 1, Batch_idx: 280, Batch_size: 30
# Epoch: 1, Batch_idx: 281, Batch_size: 30
# Epoch: 1, Batch_idx: 282, Batch_size: 30
# Epoch: 1, Batch_idx: 283, Batch_size: 30
# Epoch: 1, Batch_idx: 284, Batch_size: 30
# Epoch: 1, Batch_idx: 285, Batch_size: 30
# Epoch: 1, Batch_idx: 286, Batch_size: 30
# Epoch: 1, Batch_idx: 287, Batch_size: 30
# Epoch: 1, Batch_idx: 288, Batch_size: 30
# Epoch: 1, Batch_idx: 289, Batch_size: 30
# Epoch: 1, Batch_idx: 290, Batch_size: 30
# Epoch: 1, Batch_idx: 291, Batch_size: 30
# Epoch: 1, Batch_idx: 292, Batch_size: 30
# Epoch: 1, Batch_idx: 293, Batch_size: 30
# Epoch: 1, Batch_idx: 294, Batch_size: 30
# Epoch: 1, Batch_idx: 295, Batch_size: 30
# Epoch: 1, Batch_idx: 296, Batch_size: 30
# Epoch: 1, Batch_idx: 297, Batch_size: 30
# Epoch: 1, Batch_idx: 298, Batch_size: 30
# Epoch: 1, Batch_idx: 299, Batch_size: 23
#  20%|██        | 1/5 [01:36<06:25, 96.28s/it]
# {
#   "loss": 2.5091892859732456,
#   "acc": 2.5091892859732456,
#   "precision": 2.5091892859732456,
#   "recall": 2.5091892859732456,
#   "f": 2.5091892859732456
# }
# Metrics after epoch: 1: None
# Epoch: 2, Batch_idx: 0, Batch_size: 30
# Training set [0/8993 (0%)] Loss: 2.338101
# Epoch: 2, Batch_idx: 1, Batch_size: 30
# Epoch: 2, Batch_idx: 2, Batch_size: 30
# Epoch: 2, Batch_idx: 3, Batch_size: 30
# Epoch: 2, Batch_idx: 4, Batch_size: 30
# Epoch: 2, Batch_idx: 5, Batch_size: 30
# Epoch: 2, Batch_idx: 6, Batch_size: 30
# Epoch: 2, Batch_idx: 7, Batch_size: 30
# Epoch: 2, Batch_idx: 8, Batch_size: 30
# Epoch: 2, Batch_idx: 9, Batch_size: 30
# Epoch: 2, Batch_idx: 10, Batch_size: 30
# Epoch: 2, Batch_idx: 11, Batch_size: 30
# Epoch: 2, Batch_idx: 12, Batch_size: 30
# Epoch: 2, Batch_idx: 13, Batch_size: 30
# Epoch: 2, Batch_idx: 14, Batch_size: 30
# Epoch: 2, Batch_idx: 15, Batch_size: 30
# Epoch: 2, Batch_idx: 16, Batch_size: 30
# Epoch: 2, Batch_idx: 17, Batch_size: 30
# Epoch: 2, Batch_idx: 18, Batch_size: 30
# Epoch: 2, Batch_idx: 19, Batch_size: 30
# Epoch: 2, Batch_idx: 20, Batch_size: 30
# Epoch: 2, Batch_idx: 21, Batch_size: 30
# Epoch: 2, Batch_idx: 22, Batch_size: 30
# Epoch: 2, Batch_idx: 23, Batch_size: 30
# Epoch: 2, Batch_idx: 24, Batch_size: 30
# Epoch: 2, Batch_idx: 25, Batch_size: 30
# Epoch: 2, Batch_idx: 26, Batch_size: 30
# Epoch: 2, Batch_idx: 27, Batch_size: 30
# Epoch: 2, Batch_idx: 28, Batch_size: 30
# Epoch: 2, Batch_idx: 29, Batch_size: 30
# Epoch: 2, Batch_idx: 30, Batch_size: 30
# Epoch: 2, Batch_idx: 31, Batch_size: 30
# Epoch: 2, Batch_idx: 32, Batch_size: 30
# Epoch: 2, Batch_idx: 33, Batch_size: 30
# Epoch: 2, Batch_idx: 34, Batch_size: 30
# Epoch: 2, Batch_idx: 35, Batch_size: 30
# Epoch: 2, Batch_idx: 36, Batch_size: 30
# Epoch: 2, Batch_idx: 37, Batch_size: 30
# Epoch: 2, Batch_idx: 38, Batch_size: 30
# Epoch: 2, Batch_idx: 39, Batch_size: 30
# Epoch: 2, Batch_idx: 40, Batch_size: 30
# Epoch: 2, Batch_idx: 41, Batch_size: 30
# Epoch: 2, Batch_idx: 42, Batch_size: 30
# Epoch: 2, Batch_idx: 43, Batch_size: 30
# Epoch: 2, Batch_idx: 44, Batch_size: 30
# Epoch: 2, Batch_idx: 45, Batch_size: 30
# Epoch: 2, Batch_idx: 46, Batch_size: 30
# Epoch: 2, Batch_idx: 47, Batch_size: 30
# Epoch: 2, Batch_idx: 48, Batch_size: 30
# Epoch: 2, Batch_idx: 49, Batch_size: 30
# Epoch: 2, Batch_idx: 50, Batch_size: 30
# Epoch: 2, Batch_idx: 51, Batch_size: 30
# Epoch: 2, Batch_idx: 52, Batch_size: 30
# Epoch: 2, Batch_idx: 53, Batch_size: 30
# Epoch: 2, Batch_idx: 54, Batch_size: 30
# Epoch: 2, Batch_idx: 55, Batch_size: 30
# Epoch: 2, Batch_idx: 56, Batch_size: 30
# Epoch: 2, Batch_idx: 57, Batch_size: 30
# Epoch: 2, Batch_idx: 58, Batch_size: 30
# Epoch: 2, Batch_idx: 59, Batch_size: 30
# Epoch: 2, Batch_idx: 60, Batch_size: 30
# Epoch: 2, Batch_idx: 61, Batch_size: 30
# Epoch: 2, Batch_idx: 62, Batch_size: 30
# Epoch: 2, Batch_idx: 63, Batch_size: 30
# Epoch: 2, Batch_idx: 64, Batch_size: 30
# Epoch: 2, Batch_idx: 65, Batch_size: 30
# Epoch: 2, Batch_idx: 66, Batch_size: 30
# Epoch: 2, Batch_idx: 67, Batch_size: 30
# Epoch: 2, Batch_idx: 68, Batch_size: 30
# Epoch: 2, Batch_idx: 69, Batch_size: 30
# Epoch: 2, Batch_idx: 70, Batch_size: 30
# Epoch: 2, Batch_idx: 71, Batch_size: 30
# Epoch: 2, Batch_idx: 72, Batch_size: 30
# Epoch: 2, Batch_idx: 73, Batch_size: 30
# Epoch: 2, Batch_idx: 74, Batch_size: 30
# Epoch: 2, Batch_idx: 75, Batch_size: 30
# Epoch: 2, Batch_idx: 76, Batch_size: 30
# Epoch: 2, Batch_idx: 77, Batch_size: 30
# Epoch: 2, Batch_idx: 78, Batch_size: 30
# Epoch: 2, Batch_idx: 79, Batch_size: 30
# Epoch: 2, Batch_idx: 80, Batch_size: 30
# Epoch: 2, Batch_idx: 81, Batch_size: 30
# Epoch: 2, Batch_idx: 82, Batch_size: 30
# Epoch: 2, Batch_idx: 83, Batch_size: 30
# Epoch: 2, Batch_idx: 84, Batch_size: 30
# Epoch: 2, Batch_idx: 85, Batch_size: 30
# Epoch: 2, Batch_idx: 86, Batch_size: 30
# Epoch: 2, Batch_idx: 87, Batch_size: 30
# Epoch: 2, Batch_idx: 88, Batch_size: 30
# Epoch: 2, Batch_idx: 89, Batch_size: 30
# Epoch: 2, Batch_idx: 90, Batch_size: 30
# Epoch: 2, Batch_idx: 91, Batch_size: 30
# Epoch: 2, Batch_idx: 92, Batch_size: 30
# Epoch: 2, Batch_idx: 93, Batch_size: 30
# Epoch: 2, Batch_idx: 94, Batch_size: 30
# Epoch: 2, Batch_idx: 95, Batch_size: 30
# Epoch: 2, Batch_idx: 96, Batch_size: 30
# Epoch: 2, Batch_idx: 97, Batch_size: 30
# Epoch: 2, Batch_idx: 98, Batch_size: 30
# Epoch: 2, Batch_idx: 99, Batch_size: 30
# Epoch: 2, Batch_idx: 100, Batch_size: 30
# Training set [3000/8993 (33%)] Loss: 2.196935
# Epoch: 2, Batch_idx: 101, Batch_size: 30
# Epoch: 2, Batch_idx: 102, Batch_size: 30
# Epoch: 2, Batch_idx: 103, Batch_size: 30
# Epoch: 2, Batch_idx: 104, Batch_size: 30
# Epoch: 2, Batch_idx: 105, Batch_size: 30
# Epoch: 2, Batch_idx: 106, Batch_size: 30
# Epoch: 2, Batch_idx: 107, Batch_size: 30
# Epoch: 2, Batch_idx: 108, Batch_size: 30
# Epoch: 2, Batch_idx: 109, Batch_size: 30
# Epoch: 2, Batch_idx: 110, Batch_size: 30
# Epoch: 2, Batch_idx: 111, Batch_size: 30
# Epoch: 2, Batch_idx: 112, Batch_size: 30
# Epoch: 2, Batch_idx: 113, Batch_size: 30
# Epoch: 2, Batch_idx: 114, Batch_size: 30
# Epoch: 2, Batch_idx: 115, Batch_size: 30
# Epoch: 2, Batch_idx: 116, Batch_size: 30
# Epoch: 2, Batch_idx: 117, Batch_size: 30
# Epoch: 2, Batch_idx: 118, Batch_size: 30
# Epoch: 2, Batch_idx: 119, Batch_size: 30
# Epoch: 2, Batch_idx: 120, Batch_size: 30
# Epoch: 2, Batch_idx: 121, Batch_size: 30
# Epoch: 2, Batch_idx: 122, Batch_size: 30
# Epoch: 2, Batch_idx: 123, Batch_size: 30
# Epoch: 2, Batch_idx: 124, Batch_size: 30
# Epoch: 2, Batch_idx: 125, Batch_size: 30
# Epoch: 2, Batch_idx: 126, Batch_size: 30
# Epoch: 2, Batch_idx: 127, Batch_size: 30
# Epoch: 2, Batch_idx: 128, Batch_size: 30
# Epoch: 2, Batch_idx: 129, Batch_size: 30
# Epoch: 2, Batch_idx: 130, Batch_size: 30
# Epoch: 2, Batch_idx: 131, Batch_size: 30
# Epoch: 2, Batch_idx: 132, Batch_size: 30
# Epoch: 2, Batch_idx: 133, Batch_size: 30
# Epoch: 2, Batch_idx: 134, Batch_size: 30
# Epoch: 2, Batch_idx: 135, Batch_size: 30
# Epoch: 2, Batch_idx: 136, Batch_size: 30
# Epoch: 2, Batch_idx: 137, Batch_size: 30
# Epoch: 2, Batch_idx: 138, Batch_size: 30
# Epoch: 2, Batch_idx: 139, Batch_size: 30
# Epoch: 2, Batch_idx: 140, Batch_size: 30
# Epoch: 2, Batch_idx: 141, Batch_size: 30
# Epoch: 2, Batch_idx: 142, Batch_size: 30
# Epoch: 2, Batch_idx: 143, Batch_size: 30
# Epoch: 2, Batch_idx: 144, Batch_size: 30
# Epoch: 2, Batch_idx: 145, Batch_size: 30
# Epoch: 2, Batch_idx: 146, Batch_size: 30
# Epoch: 2, Batch_idx: 147, Batch_size: 30
# Epoch: 2, Batch_idx: 148, Batch_size: 30
# Epoch: 2, Batch_idx: 149, Batch_size: 30
# Epoch: 2, Batch_idx: 150, Batch_size: 30
# Epoch: 2, Batch_idx: 151, Batch_size: 30
# Epoch: 2, Batch_idx: 152, Batch_size: 30
# Epoch: 2, Batch_idx: 153, Batch_size: 30
# Epoch: 2, Batch_idx: 154, Batch_size: 30
# Epoch: 2, Batch_idx: 155, Batch_size: 30
# Epoch: 2, Batch_idx: 156, Batch_size: 30
# Epoch: 2, Batch_idx: 157, Batch_size: 30
# Epoch: 2, Batch_idx: 158, Batch_size: 30
# Epoch: 2, Batch_idx: 159, Batch_size: 30
# Epoch: 2, Batch_idx: 160, Batch_size: 30
# Epoch: 2, Batch_idx: 161, Batch_size: 30
# Epoch: 2, Batch_idx: 162, Batch_size: 30
# Epoch: 2, Batch_idx: 163, Batch_size: 30
# Epoch: 2, Batch_idx: 164, Batch_size: 30
# Epoch: 2, Batch_idx: 165, Batch_size: 30
# Epoch: 2, Batch_idx: 166, Batch_size: 30
# Epoch: 2, Batch_idx: 167, Batch_size: 30
# Epoch: 2, Batch_idx: 168, Batch_size: 30
# Epoch: 2, Batch_idx: 169, Batch_size: 30
# Epoch: 2, Batch_idx: 170, Batch_size: 30
# Epoch: 2, Batch_idx: 171, Batch_size: 30
# Epoch: 2, Batch_idx: 172, Batch_size: 30
# Epoch: 2, Batch_idx: 173, Batch_size: 30
# Epoch: 2, Batch_idx: 174, Batch_size: 30
# Epoch: 2, Batch_idx: 175, Batch_size: 30
# Epoch: 2, Batch_idx: 176, Batch_size: 30
# Epoch: 2, Batch_idx: 177, Batch_size: 30
# Epoch: 2, Batch_idx: 178, Batch_size: 30
# Epoch: 2, Batch_idx: 179, Batch_size: 30
# Epoch: 2, Batch_idx: 180, Batch_size: 30
# Epoch: 2, Batch_idx: 181, Batch_size: 30
# Epoch: 2, Batch_idx: 182, Batch_size: 30
# Epoch: 2, Batch_idx: 183, Batch_size: 30
# Epoch: 2, Batch_idx: 184, Batch_size: 30
# Epoch: 2, Batch_idx: 185, Batch_size: 30
# Epoch: 2, Batch_idx: 186, Batch_size: 30
# Epoch: 2, Batch_idx: 187, Batch_size: 30
# Epoch: 2, Batch_idx: 188, Batch_size: 30
# Epoch: 2, Batch_idx: 189, Batch_size: 30
# Epoch: 2, Batch_idx: 190, Batch_size: 30
# Epoch: 2, Batch_idx: 191, Batch_size: 30
# Epoch: 2, Batch_idx: 192, Batch_size: 30
# Epoch: 2, Batch_idx: 193, Batch_size: 30
# Epoch: 2, Batch_idx: 194, Batch_size: 30
# Epoch: 2, Batch_idx: 195, Batch_size: 30
# Epoch: 2, Batch_idx: 196, Batch_size: 30
# Epoch: 2, Batch_idx: 197, Batch_size: 30
# Epoch: 2, Batch_idx: 198, Batch_size: 30
# Epoch: 2, Batch_idx: 199, Batch_size: 30
# Epoch: 2, Batch_idx: 200, Batch_size: 30
# Training set [6000/8993 (67%)] Loss: 2.110046
# Epoch: 2, Batch_idx: 201, Batch_size: 30
# Epoch: 2, Batch_idx: 202, Batch_size: 30
# Epoch: 2, Batch_idx: 203, Batch_size: 30
# Epoch: 2, Batch_idx: 204, Batch_size: 30
# Epoch: 2, Batch_idx: 205, Batch_size: 30
# Epoch: 2, Batch_idx: 206, Batch_size: 30
# Epoch: 2, Batch_idx: 207, Batch_size: 30
# Epoch: 2, Batch_idx: 208, Batch_size: 30
# Epoch: 2, Batch_idx: 209, Batch_size: 30
# Epoch: 2, Batch_idx: 210, Batch_size: 30
# Epoch: 2, Batch_idx: 211, Batch_size: 30
# Epoch: 2, Batch_idx: 212, Batch_size: 30
# Epoch: 2, Batch_idx: 213, Batch_size: 30
# Epoch: 2, Batch_idx: 214, Batch_size: 30
# Epoch: 2, Batch_idx: 215, Batch_size: 30
# Epoch: 2, Batch_idx: 216, Batch_size: 30
# Epoch: 2, Batch_idx: 217, Batch_size: 30
# Epoch: 2, Batch_idx: 218, Batch_size: 30
# Epoch: 2, Batch_idx: 219, Batch_size: 30
# Epoch: 2, Batch_idx: 220, Batch_size: 30
# Epoch: 2, Batch_idx: 221, Batch_size: 30
# Epoch: 2, Batch_idx: 222, Batch_size: 30
# Epoch: 2, Batch_idx: 223, Batch_size: 30
# Epoch: 2, Batch_idx: 224, Batch_size: 30
# Epoch: 2, Batch_idx: 225, Batch_size: 30
# Epoch: 2, Batch_idx: 226, Batch_size: 30
# Epoch: 2, Batch_idx: 227, Batch_size: 30
# Epoch: 2, Batch_idx: 228, Batch_size: 30
# Epoch: 2, Batch_idx: 229, Batch_size: 30
# Epoch: 2, Batch_idx: 230, Batch_size: 30
# Epoch: 2, Batch_idx: 231, Batch_size: 30
# Epoch: 2, Batch_idx: 232, Batch_size: 30
# Epoch: 2, Batch_idx: 233, Batch_size: 30
# Epoch: 2, Batch_idx: 234, Batch_size: 30
# Epoch: 2, Batch_idx: 235, Batch_size: 30
# Epoch: 2, Batch_idx: 236, Batch_size: 30
# Epoch: 2, Batch_idx: 237, Batch_size: 30
# Epoch: 2, Batch_idx: 238, Batch_size: 30
# Epoch: 2, Batch_idx: 239, Batch_size: 30
# Epoch: 2, Batch_idx: 240, Batch_size: 30
# Epoch: 2, Batch_idx: 241, Batch_size: 30
# Epoch: 2, Batch_idx: 242, Batch_size: 30
# Epoch: 2, Batch_idx: 243, Batch_size: 30
# Epoch: 2, Batch_idx: 244, Batch_size: 30
# Epoch: 2, Batch_idx: 245, Batch_size: 30
# Epoch: 2, Batch_idx: 246, Batch_size: 30
# Epoch: 2, Batch_idx: 247, Batch_size: 30
# Epoch: 2, Batch_idx: 248, Batch_size: 30
# Epoch: 2, Batch_idx: 249, Batch_size: 30
# Epoch: 2, Batch_idx: 250, Batch_size: 30
# Epoch: 2, Batch_idx: 251, Batch_size: 30
# Epoch: 2, Batch_idx: 252, Batch_size: 30
# Epoch: 2, Batch_idx: 253, Batch_size: 30
# Epoch: 2, Batch_idx: 254, Batch_size: 30
# Epoch: 2, Batch_idx: 255, Batch_size: 30
# Epoch: 2, Batch_idx: 256, Batch_size: 30
# Epoch: 2, Batch_idx: 257, Batch_size: 30
# Epoch: 2, Batch_idx: 258, Batch_size: 30
# Epoch: 2, Batch_idx: 259, Batch_size: 30
# Epoch: 2, Batch_idx: 260, Batch_size: 30
# Epoch: 2, Batch_idx: 261, Batch_size: 30
# Epoch: 2, Batch_idx: 262, Batch_size: 30
# Epoch: 2, Batch_idx: 263, Batch_size: 30
# Epoch: 2, Batch_idx: 264, Batch_size: 30
# Epoch: 2, Batch_idx: 265, Batch_size: 30
# Epoch: 2, Batch_idx: 266, Batch_size: 30
# Epoch: 2, Batch_idx: 267, Batch_size: 30
# Epoch: 2, Batch_idx: 268, Batch_size: 30
# Epoch: 2, Batch_idx: 269, Batch_size: 30
# Epoch: 2, Batch_idx: 270, Batch_size: 30
# Epoch: 2, Batch_idx: 271, Batch_size: 30
# Epoch: 2, Batch_idx: 272, Batch_size: 30
# Epoch: 2, Batch_idx: 273, Batch_size: 30
# Epoch: 2, Batch_idx: 274, Batch_size: 30
# Epoch: 2, Batch_idx: 275, Batch_size: 30
# Epoch: 2, Batch_idx: 276, Batch_size: 30
# Epoch: 2, Batch_idx: 277, Batch_size: 30
# Epoch: 2, Batch_idx: 278, Batch_size: 30
# Epoch: 2, Batch_idx: 279, Batch_size: 30
# Epoch: 2, Batch_idx: 280, Batch_size: 30
# Epoch: 2, Batch_idx: 281, Batch_size: 30
# Epoch: 2, Batch_idx: 282, Batch_size: 30
# Epoch: 2, Batch_idx: 283, Batch_size: 30
# Epoch: 2, Batch_idx: 284, Batch_size: 30
# Epoch: 2, Batch_idx: 285, Batch_size: 30
# Epoch: 2, Batch_idx: 286, Batch_size: 30
# Epoch: 2, Batch_idx: 287, Batch_size: 30
# Epoch: 2, Batch_idx: 288, Batch_size: 30
# Epoch: 2, Batch_idx: 289, Batch_size: 30
# Epoch: 2, Batch_idx: 290, Batch_size: 30
# Epoch: 2, Batch_idx: 291, Batch_size: 30
# Epoch: 2, Batch_idx: 292, Batch_size: 30
# Epoch: 2, Batch_idx: 293, Batch_size: 30
# Epoch: 2, Batch_idx: 294, Batch_size: 30
# Epoch: 2, Batch_idx: 295, Batch_size: 30
# Epoch: 2, Batch_idx: 296, Batch_size: 30
# Epoch: 2, Batch_idx: 297, Batch_size: 30
# Epoch: 2, Batch_idx: 298, Batch_size: 30
# Epoch: 2, Batch_idx: 299, Batch_size: 23
#  40%|████      | 2/5 [03:10<04:44, 94.92s/it]
# {
#   "loss": 2.0911179004713545,
#   "acc": 2.0911179004713545,
#   "precision": 2.0911179004713545,
#   "recall": 2.0911179004713545,
#   "f": 2.0911179004713545
# }
# Metrics after epoch: 2: None
# Epoch: 3, Batch_idx: 0, Batch_size: 30
# Training set [0/8993 (0%)] Loss: 2.216388
# Epoch: 3, Batch_idx: 1, Batch_size: 30
# Epoch: 3, Batch_idx: 2, Batch_size: 30
# Epoch: 3, Batch_idx: 3, Batch_size: 30
# Epoch: 3, Batch_idx: 4, Batch_size: 30
# Epoch: 3, Batch_idx: 5, Batch_size: 30
# Epoch: 3, Batch_idx: 6, Batch_size: 30
# Epoch: 3, Batch_idx: 7, Batch_size: 30
# Epoch: 3, Batch_idx: 8, Batch_size: 30
# Epoch: 3, Batch_idx: 9, Batch_size: 30
# Epoch: 3, Batch_idx: 10, Batch_size: 30
# Epoch: 3, Batch_idx: 11, Batch_size: 30
# Epoch: 3, Batch_idx: 12, Batch_size: 30
# Epoch: 3, Batch_idx: 13, Batch_size: 30
# Epoch: 3, Batch_idx: 14, Batch_size: 30
# Epoch: 3, Batch_idx: 15, Batch_size: 30
# Epoch: 3, Batch_idx: 16, Batch_size: 30
# Epoch: 3, Batch_idx: 17, Batch_size: 30
# Epoch: 3, Batch_idx: 18, Batch_size: 30
# Epoch: 3, Batch_idx: 19, Batch_size: 30
# Epoch: 3, Batch_idx: 20, Batch_size: 30
# Epoch: 3, Batch_idx: 21, Batch_size: 30
# Epoch: 3, Batch_idx: 22, Batch_size: 30
# Epoch: 3, Batch_idx: 23, Batch_size: 30
# Epoch: 3, Batch_idx: 24, Batch_size: 30
# Epoch: 3, Batch_idx: 25, Batch_size: 30
# Epoch: 3, Batch_idx: 26, Batch_size: 30
# Epoch: 3, Batch_idx: 27, Batch_size: 30
# Epoch: 3, Batch_idx: 28, Batch_size: 30
# Epoch: 3, Batch_idx: 29, Batch_size: 30
# Epoch: 3, Batch_idx: 30, Batch_size: 30
# Epoch: 3, Batch_idx: 31, Batch_size: 30
# Epoch: 3, Batch_idx: 32, Batch_size: 30
# Epoch: 3, Batch_idx: 33, Batch_size: 30
# Epoch: 3, Batch_idx: 34, Batch_size: 30
# Epoch: 3, Batch_idx: 35, Batch_size: 30
# Epoch: 3, Batch_idx: 36, Batch_size: 30
# Epoch: 3, Batch_idx: 37, Batch_size: 30
# Epoch: 3, Batch_idx: 38, Batch_size: 30
# Epoch: 3, Batch_idx: 39, Batch_size: 30
# Epoch: 3, Batch_idx: 40, Batch_size: 30
# Epoch: 3, Batch_idx: 41, Batch_size: 30
# Epoch: 3, Batch_idx: 42, Batch_size: 30
# Epoch: 3, Batch_idx: 43, Batch_size: 30
# Epoch: 3, Batch_idx: 44, Batch_size: 30
# Epoch: 3, Batch_idx: 45, Batch_size: 30
# Epoch: 3, Batch_idx: 46, Batch_size: 30
# Epoch: 3, Batch_idx: 47, Batch_size: 30
# Epoch: 3, Batch_idx: 48, Batch_size: 30
# Epoch: 3, Batch_idx: 49, Batch_size: 30
# Epoch: 3, Batch_idx: 50, Batch_size: 30
# Epoch: 3, Batch_idx: 51, Batch_size: 30
# Epoch: 3, Batch_idx: 52, Batch_size: 30
# Epoch: 3, Batch_idx: 53, Batch_size: 30
# Epoch: 3, Batch_idx: 54, Batch_size: 30
# Epoch: 3, Batch_idx: 55, Batch_size: 30
# Epoch: 3, Batch_idx: 56, Batch_size: 30
# Epoch: 3, Batch_idx: 57, Batch_size: 30
# Epoch: 3, Batch_idx: 58, Batch_size: 30
# Epoch: 3, Batch_idx: 59, Batch_size: 30
# Epoch: 3, Batch_idx: 60, Batch_size: 30
# Epoch: 3, Batch_idx: 61, Batch_size: 30
# Epoch: 3, Batch_idx: 62, Batch_size: 30
# Epoch: 3, Batch_idx: 63, Batch_size: 30
# Epoch: 3, Batch_idx: 64, Batch_size: 30
# Epoch: 3, Batch_idx: 65, Batch_size: 30
# Epoch: 3, Batch_idx: 66, Batch_size: 30
# Epoch: 3, Batch_idx: 67, Batch_size: 30
# Epoch: 3, Batch_idx: 68, Batch_size: 30
# Epoch: 3, Batch_idx: 69, Batch_size: 30
# Epoch: 3, Batch_idx: 70, Batch_size: 30
# Epoch: 3, Batch_idx: 71, Batch_size: 30
# Epoch: 3, Batch_idx: 72, Batch_size: 30
# Epoch: 3, Batch_idx: 73, Batch_size: 30
# Epoch: 3, Batch_idx: 74, Batch_size: 30
# Epoch: 3, Batch_idx: 75, Batch_size: 30
# Epoch: 3, Batch_idx: 76, Batch_size: 30
# Epoch: 3, Batch_idx: 77, Batch_size: 30
# Epoch: 3, Batch_idx: 78, Batch_size: 30
# Epoch: 3, Batch_idx: 79, Batch_size: 30
# Epoch: 3, Batch_idx: 80, Batch_size: 30
# Epoch: 3, Batch_idx: 81, Batch_size: 30
# Epoch: 3, Batch_idx: 82, Batch_size: 30
# Epoch: 3, Batch_idx: 83, Batch_size: 30
# Epoch: 3, Batch_idx: 84, Batch_size: 30
# Epoch: 3, Batch_idx: 85, Batch_size: 30
# Epoch: 3, Batch_idx: 86, Batch_size: 30
# Epoch: 3, Batch_idx: 87, Batch_size: 30
# Epoch: 3, Batch_idx: 88, Batch_size: 30
# Epoch: 3, Batch_idx: 89, Batch_size: 30
# Epoch: 3, Batch_idx: 90, Batch_size: 30
# Epoch: 3, Batch_idx: 91, Batch_size: 30
# Epoch: 3, Batch_idx: 92, Batch_size: 30
# Epoch: 3, Batch_idx: 93, Batch_size: 30
# Epoch: 3, Batch_idx: 94, Batch_size: 30
# Epoch: 3, Batch_idx: 95, Batch_size: 30
# Epoch: 3, Batch_idx: 96, Batch_size: 30
# Epoch: 3, Batch_idx: 97, Batch_size: 30
# Epoch: 3, Batch_idx: 98, Batch_size: 30
# Epoch: 3, Batch_idx: 99, Batch_size: 30
# Epoch: 3, Batch_idx: 100, Batch_size: 30
# Training set [3000/8993 (33%)] Loss: 2.115438
# Epoch: 3, Batch_idx: 101, Batch_size: 30
# Epoch: 3, Batch_idx: 102, Batch_size: 30
# Epoch: 3, Batch_idx: 103, Batch_size: 30
# Epoch: 3, Batch_idx: 104, Batch_size: 30
# Epoch: 3, Batch_idx: 105, Batch_size: 30
# Epoch: 3, Batch_idx: 106, Batch_size: 30
# Epoch: 3, Batch_idx: 107, Batch_size: 30
# Epoch: 3, Batch_idx: 108, Batch_size: 30
# Epoch: 3, Batch_idx: 109, Batch_size: 30
# Epoch: 3, Batch_idx: 110, Batch_size: 30
# Epoch: 3, Batch_idx: 111, Batch_size: 30
# Epoch: 3, Batch_idx: 112, Batch_size: 30
# Epoch: 3, Batch_idx: 113, Batch_size: 30
# Epoch: 3, Batch_idx: 114, Batch_size: 30
# Epoch: 3, Batch_idx: 115, Batch_size: 30
# Epoch: 3, Batch_idx: 116, Batch_size: 30
# Epoch: 3, Batch_idx: 117, Batch_size: 30
# Epoch: 3, Batch_idx: 118, Batch_size: 30
# Epoch: 3, Batch_idx: 119, Batch_size: 30
# Epoch: 3, Batch_idx: 120, Batch_size: 30
# Epoch: 3, Batch_idx: 121, Batch_size: 30
# Epoch: 3, Batch_idx: 122, Batch_size: 30
# Epoch: 3, Batch_idx: 123, Batch_size: 30
# Epoch: 3, Batch_idx: 124, Batch_size: 30
# Epoch: 3, Batch_idx: 125, Batch_size: 30
# Epoch: 3, Batch_idx: 126, Batch_size: 30
# Epoch: 3, Batch_idx: 127, Batch_size: 30
# Epoch: 3, Batch_idx: 128, Batch_size: 30
# Epoch: 3, Batch_idx: 129, Batch_size: 30
# Epoch: 3, Batch_idx: 130, Batch_size: 30
# Epoch: 3, Batch_idx: 131, Batch_size: 30
# Epoch: 3, Batch_idx: 132, Batch_size: 30
# Epoch: 3, Batch_idx: 133, Batch_size: 30
# Epoch: 3, Batch_idx: 134, Batch_size: 30
# Epoch: 3, Batch_idx: 135, Batch_size: 30
# Epoch: 3, Batch_idx: 136, Batch_size: 30
# Epoch: 3, Batch_idx: 137, Batch_size: 30
# Epoch: 3, Batch_idx: 138, Batch_size: 30
# Epoch: 3, Batch_idx: 139, Batch_size: 30
# Epoch: 3, Batch_idx: 140, Batch_size: 30
# Epoch: 3, Batch_idx: 141, Batch_size: 30
# Epoch: 3, Batch_idx: 142, Batch_size: 30
# Epoch: 3, Batch_idx: 143, Batch_size: 30
# Epoch: 3, Batch_idx: 144, Batch_size: 30
# Epoch: 3, Batch_idx: 145, Batch_size: 30
# Epoch: 3, Batch_idx: 146, Batch_size: 30
# Epoch: 3, Batch_idx: 147, Batch_size: 30
# Epoch: 3, Batch_idx: 148, Batch_size: 30
# Epoch: 3, Batch_idx: 149, Batch_size: 30
# Epoch: 3, Batch_idx: 150, Batch_size: 30
# Epoch: 3, Batch_idx: 151, Batch_size: 30
# Epoch: 3, Batch_idx: 152, Batch_size: 30
# Epoch: 3, Batch_idx: 153, Batch_size: 30
# Epoch: 3, Batch_idx: 154, Batch_size: 30
# Epoch: 3, Batch_idx: 155, Batch_size: 30
# Epoch: 3, Batch_idx: 156, Batch_size: 30
# Epoch: 3, Batch_idx: 157, Batch_size: 30
# Epoch: 3, Batch_idx: 158, Batch_size: 30
# Epoch: 3, Batch_idx: 159, Batch_size: 30
# Epoch: 3, Batch_idx: 160, Batch_size: 30
# Epoch: 3, Batch_idx: 161, Batch_size: 30
# Epoch: 3, Batch_idx: 162, Batch_size: 30
# Epoch: 3, Batch_idx: 163, Batch_size: 30
# Epoch: 3, Batch_idx: 164, Batch_size: 30
# Epoch: 3, Batch_idx: 165, Batch_size: 30
# Epoch: 3, Batch_idx: 166, Batch_size: 30
# Epoch: 3, Batch_idx: 167, Batch_size: 30
# Epoch: 3, Batch_idx: 168, Batch_size: 30
# Epoch: 3, Batch_idx: 169, Batch_size: 30
# Epoch: 3, Batch_idx: 170, Batch_size: 30
# Epoch: 3, Batch_idx: 171, Batch_size: 30
# Epoch: 3, Batch_idx: 172, Batch_size: 30
# Epoch: 3, Batch_idx: 173, Batch_size: 30
# Epoch: 3, Batch_idx: 174, Batch_size: 30
# Epoch: 3, Batch_idx: 175, Batch_size: 30
# Epoch: 3, Batch_idx: 176, Batch_size: 30
# Epoch: 3, Batch_idx: 177, Batch_size: 30
# Epoch: 3, Batch_idx: 178, Batch_size: 30
# Epoch: 3, Batch_idx: 179, Batch_size: 30
# Epoch: 3, Batch_idx: 180, Batch_size: 30
# Epoch: 3, Batch_idx: 181, Batch_size: 30
# Epoch: 3, Batch_idx: 182, Batch_size: 30
# Epoch: 3, Batch_idx: 183, Batch_size: 30
# Epoch: 3, Batch_idx: 184, Batch_size: 30
# Epoch: 3, Batch_idx: 185, Batch_size: 30
# Epoch: 3, Batch_idx: 186, Batch_size: 30
# Epoch: 3, Batch_idx: 187, Batch_size: 30
# Epoch: 3, Batch_idx: 188, Batch_size: 30
# Epoch: 3, Batch_idx: 189, Batch_size: 30
# Epoch: 3, Batch_idx: 190, Batch_size: 30
# Epoch: 3, Batch_idx: 191, Batch_size: 30
# Epoch: 3, Batch_idx: 192, Batch_size: 30
# Epoch: 3, Batch_idx: 193, Batch_size: 30
# Epoch: 3, Batch_idx: 194, Batch_size: 30
# Epoch: 3, Batch_idx: 195, Batch_size: 30
# Epoch: 3, Batch_idx: 196, Batch_size: 30
# Epoch: 3, Batch_idx: 197, Batch_size: 30
# Epoch: 3, Batch_idx: 198, Batch_size: 30
# Epoch: 3, Batch_idx: 199, Batch_size: 30
# Epoch: 3, Batch_idx: 200, Batch_size: 30
# Training set [6000/8993 (67%)] Loss: 1.970648
# Epoch: 3, Batch_idx: 201, Batch_size: 30
# Epoch: 3, Batch_idx: 202, Batch_size: 30
# Epoch: 3, Batch_idx: 203, Batch_size: 30
# Epoch: 3, Batch_idx: 204, Batch_size: 30
# Epoch: 3, Batch_idx: 205, Batch_size: 30
# Epoch: 3, Batch_idx: 206, Batch_size: 30
# Epoch: 3, Batch_idx: 207, Batch_size: 30
# Epoch: 3, Batch_idx: 208, Batch_size: 30
# Epoch: 3, Batch_idx: 209, Batch_size: 30
# Epoch: 3, Batch_idx: 210, Batch_size: 30
# Epoch: 3, Batch_idx: 211, Batch_size: 30
# Epoch: 3, Batch_idx: 212, Batch_size: 30
# Epoch: 3, Batch_idx: 213, Batch_size: 30
# Epoch: 3, Batch_idx: 214, Batch_size: 30
# Epoch: 3, Batch_idx: 215, Batch_size: 30
# Epoch: 3, Batch_idx: 216, Batch_size: 30
# Epoch: 3, Batch_idx: 217, Batch_size: 30
# Epoch: 3, Batch_idx: 218, Batch_size: 30
# Epoch: 3, Batch_idx: 219, Batch_size: 30
# Epoch: 3, Batch_idx: 220, Batch_size: 30
# Epoch: 3, Batch_idx: 221, Batch_size: 30
# Epoch: 3, Batch_idx: 222, Batch_size: 30
# Epoch: 3, Batch_idx: 223, Batch_size: 30
# Epoch: 3, Batch_idx: 224, Batch_size: 30
# Epoch: 3, Batch_idx: 225, Batch_size: 30
# Epoch: 3, Batch_idx: 226, Batch_size: 30
# Epoch: 3, Batch_idx: 227, Batch_size: 30
# Epoch: 3, Batch_idx: 228, Batch_size: 30
# Epoch: 3, Batch_idx: 229, Batch_size: 30
# Epoch: 3, Batch_idx: 230, Batch_size: 30
# Epoch: 3, Batch_idx: 231, Batch_size: 30
# Epoch: 3, Batch_idx: 232, Batch_size: 30
# Epoch: 3, Batch_idx: 233, Batch_size: 30
# Epoch: 3, Batch_idx: 234, Batch_size: 30
# Epoch: 3, Batch_idx: 235, Batch_size: 30
# Epoch: 3, Batch_idx: 236, Batch_size: 30
# Epoch: 3, Batch_idx: 237, Batch_size: 30
# Epoch: 3, Batch_idx: 238, Batch_size: 30
# Epoch: 3, Batch_idx: 239, Batch_size: 30
# Epoch: 3, Batch_idx: 240, Batch_size: 30
# Epoch: 3, Batch_idx: 241, Batch_size: 30
# Epoch: 3, Batch_idx: 242, Batch_size: 30
# Epoch: 3, Batch_idx: 243, Batch_size: 30
# Epoch: 3, Batch_idx: 244, Batch_size: 30
# Epoch: 3, Batch_idx: 245, Batch_size: 30
# Epoch: 3, Batch_idx: 246, Batch_size: 30
# Epoch: 3, Batch_idx: 247, Batch_size: 30
# Epoch: 3, Batch_idx: 248, Batch_size: 30
# Epoch: 3, Batch_idx: 249, Batch_size: 30
# Epoch: 3, Batch_idx: 250, Batch_size: 30
# Epoch: 3, Batch_idx: 251, Batch_size: 30
# Epoch: 3, Batch_idx: 252, Batch_size: 30
# Epoch: 3, Batch_idx: 253, Batch_size: 30
# Epoch: 3, Batch_idx: 254, Batch_size: 30
# Epoch: 3, Batch_idx: 255, Batch_size: 30
# Epoch: 3, Batch_idx: 256, Batch_size: 30
# Epoch: 3, Batch_idx: 257, Batch_size: 30
# Epoch: 3, Batch_idx: 258, Batch_size: 30
# Epoch: 3, Batch_idx: 259, Batch_size: 30
# Epoch: 3, Batch_idx: 260, Batch_size: 30
# Epoch: 3, Batch_idx: 261, Batch_size: 30
# Epoch: 3, Batch_idx: 262, Batch_size: 30
# Epoch: 3, Batch_idx: 263, Batch_size: 30
# Epoch: 3, Batch_idx: 264, Batch_size: 30
# Epoch: 3, Batch_idx: 265, Batch_size: 30
# Epoch: 3, Batch_idx: 266, Batch_size: 30
# Epoch: 3, Batch_idx: 267, Batch_size: 30
# Epoch: 3, Batch_idx: 268, Batch_size: 30
# Epoch: 3, Batch_idx: 269, Batch_size: 30
# Epoch: 3, Batch_idx: 270, Batch_size: 30
# Epoch: 3, Batch_idx: 271, Batch_size: 30
# Epoch: 3, Batch_idx: 272, Batch_size: 30
# Epoch: 3, Batch_idx: 273, Batch_size: 30
# Epoch: 3, Batch_idx: 274, Batch_size: 30
# Epoch: 3, Batch_idx: 275, Batch_size: 30
# Epoch: 3, Batch_idx: 276, Batch_size: 30
# Epoch: 3, Batch_idx: 277, Batch_size: 30
# Epoch: 3, Batch_idx: 278, Batch_size: 30
# Epoch: 3, Batch_idx: 279, Batch_size: 30
# Epoch: 3, Batch_idx: 280, Batch_size: 30
# Epoch: 3, Batch_idx: 281, Batch_size: 30
# Epoch: 3, Batch_idx: 282, Batch_size: 30
# Epoch: 3, Batch_idx: 283, Batch_size: 30
# Epoch: 3, Batch_idx: 284, Batch_size: 30
# Epoch: 3, Batch_idx: 285, Batch_size: 30
# Epoch: 3, Batch_idx: 286, Batch_size: 30
# Epoch: 3, Batch_idx: 287, Batch_size: 30
# Epoch: 3, Batch_idx: 288, Batch_size: 30
# Epoch: 3, Batch_idx: 289, Batch_size: 30
# Epoch: 3, Batch_idx: 290, Batch_size: 30
# Epoch: 3, Batch_idx: 291, Batch_size: 30
# Epoch: 3, Batch_idx: 292, Batch_size: 30
# Epoch: 3, Batch_idx: 293, Batch_size: 30
# Epoch: 3, Batch_idx: 294, Batch_size: 30
# Epoch: 3, Batch_idx: 295, Batch_size: 30
# Epoch: 3, Batch_idx: 296, Batch_size: 30
# Epoch: 3, Batch_idx: 297, Batch_size: 30
# Epoch: 3, Batch_idx: 298, Batch_size: 30
# Epoch: 3, Batch_idx: 299, Batch_size: 23
#  60%|██████    | 3/5 [04:43<03:08, 94.18s/it]
# {
#   "loss": 2.065237810445386,
#   "acc": 2.065237810445386,
#   "precision": 2.065237810445386,
#   "recall": 2.065237810445386,
#   "f": 2.065237810445386
# }
# Metrics after epoch: 3: None
# Epoch: 4, Batch_idx: 0, Batch_size: 30
# Training set [0/8993 (0%)] Loss: 2.116463
# Epoch: 4, Batch_idx: 1, Batch_size: 30
# Epoch: 4, Batch_idx: 2, Batch_size: 30
# Epoch: 4, Batch_idx: 3, Batch_size: 30
# Epoch: 4, Batch_idx: 4, Batch_size: 30
# Epoch: 4, Batch_idx: 5, Batch_size: 30
# Epoch: 4, Batch_idx: 6, Batch_size: 30
# Epoch: 4, Batch_idx: 7, Batch_size: 30
# Epoch: 4, Batch_idx: 8, Batch_size: 30
# Epoch: 4, Batch_idx: 9, Batch_size: 30
# Epoch: 4, Batch_idx: 10, Batch_size: 30
# Epoch: 4, Batch_idx: 11, Batch_size: 30
# Epoch: 4, Batch_idx: 12, Batch_size: 30
# Epoch: 4, Batch_idx: 13, Batch_size: 30
# Epoch: 4, Batch_idx: 14, Batch_size: 30
# Epoch: 4, Batch_idx: 15, Batch_size: 30
# Epoch: 4, Batch_idx: 16, Batch_size: 30
# Epoch: 4, Batch_idx: 17, Batch_size: 30
# Epoch: 4, Batch_idx: 18, Batch_size: 30
# Epoch: 4, Batch_idx: 19, Batch_size: 30
# Epoch: 4, Batch_idx: 20, Batch_size: 30
# Epoch: 4, Batch_idx: 21, Batch_size: 30
# Epoch: 4, Batch_idx: 22, Batch_size: 30
# Epoch: 4, Batch_idx: 23, Batch_size: 30
# Epoch: 4, Batch_idx: 24, Batch_size: 30
# Epoch: 4, Batch_idx: 25, Batch_size: 30
# Epoch: 4, Batch_idx: 26, Batch_size: 30
# Epoch: 4, Batch_idx: 27, Batch_size: 30
# Epoch: 4, Batch_idx: 28, Batch_size: 30
# Epoch: 4, Batch_idx: 29, Batch_size: 30
# Epoch: 4, Batch_idx: 30, Batch_size: 30
# Epoch: 4, Batch_idx: 31, Batch_size: 30
# Epoch: 4, Batch_idx: 32, Batch_size: 30
# Epoch: 4, Batch_idx: 33, Batch_size: 30
# Epoch: 4, Batch_idx: 34, Batch_size: 30
# Epoch: 4, Batch_idx: 35, Batch_size: 30
# Epoch: 4, Batch_idx: 36, Batch_size: 30
# Epoch: 4, Batch_idx: 37, Batch_size: 30
# Epoch: 4, Batch_idx: 38, Batch_size: 30
# Epoch: 4, Batch_idx: 39, Batch_size: 30
# Epoch: 4, Batch_idx: 40, Batch_size: 30
# Epoch: 4, Batch_idx: 41, Batch_size: 30
# Epoch: 4, Batch_idx: 42, Batch_size: 30
# Epoch: 4, Batch_idx: 43, Batch_size: 30
# Epoch: 4, Batch_idx: 44, Batch_size: 30
# Epoch: 4, Batch_idx: 45, Batch_size: 30
# Epoch: 4, Batch_idx: 46, Batch_size: 30
# Epoch: 4, Batch_idx: 47, Batch_size: 30
# Epoch: 4, Batch_idx: 48, Batch_size: 30
# Epoch: 4, Batch_idx: 49, Batch_size: 30
# Epoch: 4, Batch_idx: 50, Batch_size: 30
# Epoch: 4, Batch_idx: 51, Batch_size: 30
# Epoch: 4, Batch_idx: 52, Batch_size: 30
# Epoch: 4, Batch_idx: 53, Batch_size: 30
# Epoch: 4, Batch_idx: 54, Batch_size: 30
# Epoch: 4, Batch_idx: 55, Batch_size: 30
# Epoch: 4, Batch_idx: 56, Batch_size: 30
# Epoch: 4, Batch_idx: 57, Batch_size: 30
# Epoch: 4, Batch_idx: 58, Batch_size: 30
# Epoch: 4, Batch_idx: 59, Batch_size: 30
# Epoch: 4, Batch_idx: 60, Batch_size: 30
# Epoch: 4, Batch_idx: 61, Batch_size: 30
# Epoch: 4, Batch_idx: 62, Batch_size: 30
# Epoch: 4, Batch_idx: 63, Batch_size: 30
# Epoch: 4, Batch_idx: 64, Batch_size: 30
# Epoch: 4, Batch_idx: 65, Batch_size: 30
# Epoch: 4, Batch_idx: 66, Batch_size: 30
# Epoch: 4, Batch_idx: 67, Batch_size: 30
# Epoch: 4, Batch_idx: 68, Batch_size: 30
# Epoch: 4, Batch_idx: 69, Batch_size: 30
# Epoch: 4, Batch_idx: 70, Batch_size: 30
# Epoch: 4, Batch_idx: 71, Batch_size: 30
# Epoch: 4, Batch_idx: 72, Batch_size: 30
# Epoch: 4, Batch_idx: 73, Batch_size: 30
# Epoch: 4, Batch_idx: 74, Batch_size: 30
# Epoch: 4, Batch_idx: 75, Batch_size: 30
# Epoch: 4, Batch_idx: 76, Batch_size: 30
# Epoch: 4, Batch_idx: 77, Batch_size: 30
# Epoch: 4, Batch_idx: 78, Batch_size: 30
# Epoch: 4, Batch_idx: 79, Batch_size: 30
# Epoch: 4, Batch_idx: 80, Batch_size: 30
# Epoch: 4, Batch_idx: 81, Batch_size: 30
# Epoch: 4, Batch_idx: 82, Batch_size: 30
# Epoch: 4, Batch_idx: 83, Batch_size: 30
# Epoch: 4, Batch_idx: 84, Batch_size: 30
# Epoch: 4, Batch_idx: 85, Batch_size: 30
# Epoch: 4, Batch_idx: 86, Batch_size: 30
# Epoch: 4, Batch_idx: 87, Batch_size: 30
# Epoch: 4, Batch_idx: 88, Batch_size: 30
# Epoch: 4, Batch_idx: 89, Batch_size: 30
# Epoch: 4, Batch_idx: 90, Batch_size: 30
# Epoch: 4, Batch_idx: 91, Batch_size: 30
# Epoch: 4, Batch_idx: 92, Batch_size: 30
# Epoch: 4, Batch_idx: 93, Batch_size: 30
# Epoch: 4, Batch_idx: 94, Batch_size: 30
# Epoch: 4, Batch_idx: 95, Batch_size: 30
# Epoch: 4, Batch_idx: 96, Batch_size: 30
# Epoch: 4, Batch_idx: 97, Batch_size: 30
# Epoch: 4, Batch_idx: 98, Batch_size: 30
# Epoch: 4, Batch_idx: 99, Batch_size: 30
# Epoch: 4, Batch_idx: 100, Batch_size: 30
# Training set [3000/8993 (33%)] Loss: 2.012714
# Epoch: 4, Batch_idx: 101, Batch_size: 30
# Epoch: 4, Batch_idx: 102, Batch_size: 30
# Epoch: 4, Batch_idx: 103, Batch_size: 30
# Epoch: 4, Batch_idx: 104, Batch_size: 30
# Epoch: 4, Batch_idx: 105, Batch_size: 30
# Epoch: 4, Batch_idx: 106, Batch_size: 30
# Epoch: 4, Batch_idx: 107, Batch_size: 30
# Epoch: 4, Batch_idx: 108, Batch_size: 30
# Epoch: 4, Batch_idx: 109, Batch_size: 30
# Epoch: 4, Batch_idx: 110, Batch_size: 30
# Epoch: 4, Batch_idx: 111, Batch_size: 30
# Epoch: 4, Batch_idx: 112, Batch_size: 30
# Epoch: 4, Batch_idx: 113, Batch_size: 30
# Epoch: 4, Batch_idx: 114, Batch_size: 30
# Epoch: 4, Batch_idx: 115, Batch_size: 30
# Epoch: 4, Batch_idx: 116, Batch_size: 30
# Epoch: 4, Batch_idx: 117, Batch_size: 30
# Epoch: 4, Batch_idx: 118, Batch_size: 30
# Epoch: 4, Batch_idx: 119, Batch_size: 30
# Epoch: 4, Batch_idx: 120, Batch_size: 30
# Epoch: 4, Batch_idx: 121, Batch_size: 30
# Epoch: 4, Batch_idx: 122, Batch_size: 30
# Epoch: 4, Batch_idx: 123, Batch_size: 30
# Epoch: 4, Batch_idx: 124, Batch_size: 30
# Epoch: 4, Batch_idx: 125, Batch_size: 30
# Epoch: 4, Batch_idx: 126, Batch_size: 30
# Epoch: 4, Batch_idx: 127, Batch_size: 30
# Epoch: 4, Batch_idx: 128, Batch_size: 30
# Epoch: 4, Batch_idx: 129, Batch_size: 30
# Epoch: 4, Batch_idx: 130, Batch_size: 30
# Epoch: 4, Batch_idx: 131, Batch_size: 30
# Epoch: 4, Batch_idx: 132, Batch_size: 30
# Epoch: 4, Batch_idx: 133, Batch_size: 30
# Epoch: 4, Batch_idx: 134, Batch_size: 30
# Epoch: 4, Batch_idx: 135, Batch_size: 30
# Epoch: 4, Batch_idx: 136, Batch_size: 30
# Epoch: 4, Batch_idx: 137, Batch_size: 30
# Epoch: 4, Batch_idx: 138, Batch_size: 30
# Epoch: 4, Batch_idx: 139, Batch_size: 30
# Epoch: 4, Batch_idx: 140, Batch_size: 30
# Epoch: 4, Batch_idx: 141, Batch_size: 30
# Epoch: 4, Batch_idx: 142, Batch_size: 30
# Epoch: 4, Batch_idx: 143, Batch_size: 30
# Epoch: 4, Batch_idx: 144, Batch_size: 30
# Epoch: 4, Batch_idx: 145, Batch_size: 30
# Epoch: 4, Batch_idx: 146, Batch_size: 30
# Epoch: 4, Batch_idx: 147, Batch_size: 30
# Epoch: 4, Batch_idx: 148, Batch_size: 30
# Epoch: 4, Batch_idx: 149, Batch_size: 30
# Epoch: 4, Batch_idx: 150, Batch_size: 30
# Epoch: 4, Batch_idx: 151, Batch_size: 30
# Epoch: 4, Batch_idx: 152, Batch_size: 30
# Epoch: 4, Batch_idx: 153, Batch_size: 30
# Epoch: 4, Batch_idx: 154, Batch_size: 30
# Epoch: 4, Batch_idx: 155, Batch_size: 30
# Epoch: 4, Batch_idx: 156, Batch_size: 30
# Epoch: 4, Batch_idx: 157, Batch_size: 30
# Epoch: 4, Batch_idx: 158, Batch_size: 30
# Epoch: 4, Batch_idx: 159, Batch_size: 30
# Epoch: 4, Batch_idx: 160, Batch_size: 30
# Epoch: 4, Batch_idx: 161, Batch_size: 30
# Epoch: 4, Batch_idx: 162, Batch_size: 30
# Epoch: 4, Batch_idx: 163, Batch_size: 30
# Epoch: 4, Batch_idx: 164, Batch_size: 30
# Epoch: 4, Batch_idx: 165, Batch_size: 30
# Epoch: 4, Batch_idx: 166, Batch_size: 30
# Epoch: 4, Batch_idx: 167, Batch_size: 30
# Epoch: 4, Batch_idx: 168, Batch_size: 30
# Epoch: 4, Batch_idx: 169, Batch_size: 30
# Epoch: 4, Batch_idx: 170, Batch_size: 30
# Epoch: 4, Batch_idx: 171, Batch_size: 30
# Epoch: 4, Batch_idx: 172, Batch_size: 30
# Epoch: 4, Batch_idx: 173, Batch_size: 30
# Epoch: 4, Batch_idx: 174, Batch_size: 30
# Epoch: 4, Batch_idx: 175, Batch_size: 30
# Epoch: 4, Batch_idx: 176, Batch_size: 30
# Epoch: 4, Batch_idx: 177, Batch_size: 30
# Epoch: 4, Batch_idx: 178, Batch_size: 30
# Epoch: 4, Batch_idx: 179, Batch_size: 30
# Epoch: 4, Batch_idx: 180, Batch_size: 30
# Epoch: 4, Batch_idx: 181, Batch_size: 30
# Epoch: 4, Batch_idx: 182, Batch_size: 30
# Epoch: 4, Batch_idx: 183, Batch_size: 30
# Epoch: 4, Batch_idx: 184, Batch_size: 30
# Epoch: 4, Batch_idx: 185, Batch_size: 30
# Epoch: 4, Batch_idx: 186, Batch_size: 30
# Epoch: 4, Batch_idx: 187, Batch_size: 30
# Epoch: 4, Batch_idx: 188, Batch_size: 30
# Epoch: 4, Batch_idx: 189, Batch_size: 30
# Epoch: 4, Batch_idx: 190, Batch_size: 30
# Epoch: 4, Batch_idx: 191, Batch_size: 30
# Epoch: 4, Batch_idx: 192, Batch_size: 30
# Epoch: 4, Batch_idx: 193, Batch_size: 30
# Epoch: 4, Batch_idx: 194, Batch_size: 30
# Epoch: 4, Batch_idx: 195, Batch_size: 30
# Epoch: 4, Batch_idx: 196, Batch_size: 30
# Epoch: 4, Batch_idx: 197, Batch_size: 30
# Epoch: 4, Batch_idx: 198, Batch_size: 30
# Epoch: 4, Batch_idx: 199, Batch_size: 30
# Epoch: 4, Batch_idx: 200, Batch_size: 30
# Training set [6000/8993 (67%)] Loss: 2.211364
# Epoch: 4, Batch_idx: 201, Batch_size: 30
# Epoch: 4, Batch_idx: 202, Batch_size: 30
# Epoch: 4, Batch_idx: 203, Batch_size: 30
# Epoch: 4, Batch_idx: 204, Batch_size: 30
# Epoch: 4, Batch_idx: 205, Batch_size: 30
# Epoch: 4, Batch_idx: 206, Batch_size: 30
# Epoch: 4, Batch_idx: 207, Batch_size: 30
# Epoch: 4, Batch_idx: 208, Batch_size: 30
# Epoch: 4, Batch_idx: 209, Batch_size: 30
# Epoch: 4, Batch_idx: 210, Batch_size: 30
# Epoch: 4, Batch_idx: 211, Batch_size: 30
# Epoch: 4, Batch_idx: 212, Batch_size: 30
# Epoch: 4, Batch_idx: 213, Batch_size: 30
# Epoch: 4, Batch_idx: 214, Batch_size: 30
# Epoch: 4, Batch_idx: 215, Batch_size: 30
# Epoch: 4, Batch_idx: 216, Batch_size: 30
# Epoch: 4, Batch_idx: 217, Batch_size: 30
# Epoch: 4, Batch_idx: 218, Batch_size: 30
# Epoch: 4, Batch_idx: 219, Batch_size: 30
# Epoch: 4, Batch_idx: 220, Batch_size: 30
# Epoch: 4, Batch_idx: 221, Batch_size: 30
# Epoch: 4, Batch_idx: 222, Batch_size: 30
# Epoch: 4, Batch_idx: 223, Batch_size: 30
# Epoch: 4, Batch_idx: 224, Batch_size: 30
# Epoch: 4, Batch_idx: 225, Batch_size: 30
# Epoch: 4, Batch_idx: 226, Batch_size: 30
# Epoch: 4, Batch_idx: 227, Batch_size: 30
# Epoch: 4, Batch_idx: 228, Batch_size: 30
# Epoch: 4, Batch_idx: 229, Batch_size: 30
# Epoch: 4, Batch_idx: 230, Batch_size: 30
# Epoch: 4, Batch_idx: 231, Batch_size: 30
# Epoch: 4, Batch_idx: 232, Batch_size: 30
# Epoch: 4, Batch_idx: 233, Batch_size: 30
# Epoch: 4, Batch_idx: 234, Batch_size: 30
# Epoch: 4, Batch_idx: 235, Batch_size: 30
# Epoch: 4, Batch_idx: 236, Batch_size: 30
# Epoch: 4, Batch_idx: 237, Batch_size: 30
# Epoch: 4, Batch_idx: 238, Batch_size: 30
# Epoch: 4, Batch_idx: 239, Batch_size: 30
# Epoch: 4, Batch_idx: 240, Batch_size: 30
# Epoch: 4, Batch_idx: 241, Batch_size: 30
# Epoch: 4, Batch_idx: 242, Batch_size: 30
# Epoch: 4, Batch_idx: 243, Batch_size: 30
# Epoch: 4, Batch_idx: 244, Batch_size: 30
# Epoch: 4, Batch_idx: 245, Batch_size: 30
# Epoch: 4, Batch_idx: 246, Batch_size: 30
# Epoch: 4, Batch_idx: 247, Batch_size: 30
# Epoch: 4, Batch_idx: 248, Batch_size: 30
# Epoch: 4, Batch_idx: 249, Batch_size: 30
# ...
# Epoch: 4, Batch_idx: 257, Batch_size: 30
# Epoch: 4, Batch_idx: 258, Batch_size: 30
# Epoch: 4, Batch_idx: 259, Batch_size: 30
# Epoch: 4, Batch_idx: 260, Batch_size: 30
# Epoch: 4, Batch_idx: 261, Batch_size: 30
# Epoch: 4, Batch_idx: 262, Batch_size: 30
# Epoch: 4, Batch_idx: 263, Batch_size: 30
# Epoch: 4, Batch_idx: 264, Batch_size: 30
# Epoch: 4, Batch_idx: 265, Batch_size: 30
# Epoch: 4, Batch_idx: 266, Batch_size: 30
# Epoch: 4, Batch_idx: 267, Batch_size: 30
# Epoch: 4, Batch_idx: 268, Batch_size: 30
# Epoch: 4, Batch_idx: 269, Batch_size: 30
# Epoch: 4, Batch_idx: 270, Batch_size: 30
# Epoch: 4, Batch_idx: 271, Batch_size: 30
# Epoch: 4, Batch_idx: 272, Batch_size: 30
# Epoch: 4, Batch_idx: 273, Batch_size: 30
# Epoch: 4, Batch_idx: 274, Batch_size: 30
# Epoch: 4, Batch_idx: 275, Batch_size: 30
# Epoch: 4, Batch_idx: 276, Batch_size: 30
# Epoch: 4, Batch_idx: 277, Batch_size: 30
# Epoch: 4, Batch_idx: 278, Batch_size: 30
# Epoch: 4, Batch_idx: 279, Batch_size: 30
# Epoch: 4, Batch_idx: 280, Batch_size: 30
# Epoch: 4, Batch_idx: 281, Batch_size: 30
# Epoch: 4, Batch_idx: 282, Batch_size: 30
# Epoch: 4, Batch_idx: 283, Batch_size: 30
# Epoch: 4, Batch_idx: 284, Batch_size: 30
# Epoch: 4, Batch_idx: 285, Batch_size: 30
# Epoch: 4, Batch_idx: 286, Batch_size: 30
# Epoch: 4, Batch_idx: 287, Batch_size: 30
# Epoch: 4, Batch_idx: 288, Batch_size: 30
# Epoch: 4, Batch_idx: 289, Batch_size: 30
# Epoch: 4, Batch_idx: 290, Batch_size: 30
# Epoch: 4, Batch_idx: 291, Batch_size: 30
# Epoch: 4, Batch_idx: 292, Batch_size: 30
# Epoch: 4, Batch_idx: 293, Batch_size: 30
# Epoch: 4, Batch_idx: 294, Batch_size: 30
# Epoch: 4, Batch_idx: 295, Batch_size: 30
# Epoch: 4, Batch_idx: 296, Batch_size: 30
# Epoch: 4, Batch_idx: 297, Batch_size: 30
# Epoch: 4, Batch_idx: 298, Batch_size: 30
# Epoch: 4, Batch_idx: 299, Batch_size: 23
#  80%|████████  | 4/5 [08:34<02:28, 148.04s/it]
# {
#   "loss": 2.040955373483111,
#   "acc": 2.040955373483111,
#   "precision": 2.040955373483111,
#   "recall": 2.040955373483111,
#   "f": 2.040955373483111
# }
# Metrics after epoch: 4: None
# Epoch: 5, Batch_idx: 0, Batch_size: 30
# Training set [0/8993 (0%)] Loss: 2.220954
# Epoch: 5, Batch_idx: 1, Batch_size: 30
# Epoch: 5, Batch_idx: 2, Batch_size: 30
# Epoch: 5, Batch_idx: 3, Batch_size: 30
# Epoch: 5, Batch_idx: 4, Batch_size: 30
# Epoch: 5, Batch_idx: 5, Batch_size: 30
# Epoch: 5, Batch_idx: 6, Batch_size: 30
# Epoch: 5, Batch_idx: 7, Batch_size: 30
# Epoch: 5, Batch_idx: 8, Batch_size: 30
# Epoch: 5, Batch_idx: 9, Batch_size: 30
# Epoch: 5, Batch_idx: 10, Batch_size: 30
# Epoch: 5, Batch_idx: 11, Batch_size: 30
# Epoch: 5, Batch_idx: 12, Batch_size: 30
# Epoch: 5, Batch_idx: 13, Batch_size: 30
# Epoch: 5, Batch_idx: 14, Batch_size: 30
# Epoch: 5, Batch_idx: 15, Batch_size: 30
# Epoch: 5, Batch_idx: 16, Batch_size: 30
# Epoch: 5, Batch_idx: 17, Batch_size: 30
# Epoch: 5, Batch_idx: 18, Batch_size: 30
# Epoch: 5, Batch_idx: 19, Batch_size: 30
# Epoch: 5, Batch_idx: 20, Batch_size: 30
# Epoch: 5, Batch_idx: 21, Batch_size: 30
# Epoch: 5, Batch_idx: 22, Batch_size: 30
# Epoch: 5, Batch_idx: 23, Batch_size: 30
# Epoch: 5, Batch_idx: 24, Batch_size: 30
# Epoch: 5, Batch_idx: 25, Batch_size: 30
# Epoch: 5, Batch_idx: 26, Batch_size: 30
# Epoch: 5, Batch_idx: 27, Batch_size: 30
# Epoch: 5, Batch_idx: 28, Batch_size: 30
# Epoch: 5, Batch_idx: 29, Batch_size: 30
# Epoch: 5, Batch_idx: 30, Batch_size: 30
# Epoch: 5, Batch_idx: 31, Batch_size: 30
# Epoch: 5, Batch_idx: 32, Batch_size: 30
# Epoch: 5, Batch_idx: 33, Batch_size: 30
# Epoch: 5, Batch_idx: 34, Batch_size: 30
# Epoch: 5, Batch_idx: 35, Batch_size: 30
# Epoch: 5, Batch_idx: 36, Batch_size: 30
# Epoch: 5, Batch_idx: 37, Batch_size: 30
# Epoch: 5, Batch_idx: 38, Batch_size: 30
# Epoch: 5, Batch_idx: 39, Batch_size: 30
# Epoch: 5, Batch_idx: 40, Batch_size: 30
# Epoch: 5, Batch_idx: 41, Batch_size: 30
# Epoch: 5, Batch_idx: 42, Batch_size: 30
# Epoch: 5, Batch_idx: 43, Batch_size: 30
# Epoch: 5, Batch_idx: 44, Batch_size: 30
# Epoch: 5, Batch_idx: 45, Batch_size: 30
# Epoch: 5, Batch_idx: 46, Batch_size: 30
# Epoch: 5, Batch_idx: 47, Batch_size: 30
# Epoch: 5, Batch_idx: 48, Batch_size: 30
# Epoch: 5, Batch_idx: 49, Batch_size: 30
# Epoch: 5, Batch_idx: 50, Batch_size: 30
# Epoch: 5, Batch_idx: 51, Batch_size: 30
# Epoch: 5, Batch_idx: 52, Batch_size: 30
# Epoch: 5, Batch_idx: 53, Batch_size: 30
# Epoch: 5, Batch_idx: 54, Batch_size: 30
# Epoch: 5, Batch_idx: 55, Batch_size: 30
# Epoch: 5, Batch_idx: 56, Batch_size: 30
# Epoch: 5, Batch_idx: 57, Batch_size: 30
# Epoch: 5, Batch_idx: 58, Batch_size: 30
# Epoch: 5, Batch_idx: 59, Batch_size: 30
# Epoch: 5, Batch_idx: 60, Batch_size: 30
# Epoch: 5, Batch_idx: 61, Batch_size: 30
# Epoch: 5, Batch_idx: 62, Batch_size: 30
# Epoch: 5, Batch_idx: 63, Batch_size: 30
# Epoch: 5, Batch_idx: 64, Batch_size: 30
# Epoch: 5, Batch_idx: 65, Batch_size: 30
# Epoch: 5, Batch_idx: 66, Batch_size: 30
# Epoch: 5, Batch_idx: 67, Batch_size: 30
# Epoch: 5, Batch_idx: 68, Batch_size: 30
# Epoch: 5, Batch_idx: 69, Batch_size: 30
# Epoch: 5, Batch_idx: 70, Batch_size: 30
# Epoch: 5, Batch_idx: 71, Batch_size: 30
# Epoch: 5, Batch_idx: 72, Batch_size: 30
# Epoch: 5, Batch_idx: 73, Batch_size: 30
# Epoch: 5, Batch_idx: 74, Batch_size: 30
# Epoch: 5, Batch_idx: 75, Batch_size: 30
# Epoch: 5, Batch_idx: 76, Batch_size: 30
# Epoch: 5, Batch_idx: 77, Batch_size: 30
# Epoch: 5, Batch_idx: 78, Batch_size: 30
# Epoch: 5, Batch_idx: 79, Batch_size: 30
# Epoch: 5, Batch_idx: 80, Batch_size: 30
# Epoch: 5, Batch_idx: 81, Batch_size: 30
# Epoch: 5, Batch_idx: 82, Batch_size: 30
# Epoch: 5, Batch_idx: 83, Batch_size: 30
# Epoch: 5, Batch_idx: 84, Batch_size: 30
# Epoch: 5, Batch_idx: 85, Batch_size: 30
# Epoch: 5, Batch_idx: 86, Batch_size: 30
# Epoch: 5, Batch_idx: 87, Batch_size: 30
# Epoch: 5, Batch_idx: 88, Batch_size: 30
# Epoch: 5, Batch_idx: 89, Batch_size: 30
# Epoch: 5, Batch_idx: 90, Batch_size: 30
# Epoch: 5, Batch_idx: 91, Batch_size: 30
# Epoch: 5, Batch_idx: 92, Batch_size: 30
# Epoch: 5, Batch_idx: 93, Batch_size: 30
# Epoch: 5, Batch_idx: 94, Batch_size: 30
# Epoch: 5, Batch_idx: 95, Batch_size: 30
# Epoch: 5, Batch_idx: 96, Batch_size: 30
# Epoch: 5, Batch_idx: 97, Batch_size: 30
# Epoch: 5, Batch_idx: 98, Batch_size: 30
# Epoch: 5, Batch_idx: 99, Batch_size: 30
# Epoch: 5, Batch_idx: 100, Batch_size: 30
# Training set [3000/8993 (33%)] Loss: 1.958467
# Epoch: 5, Batch_idx: 101, Batch_size: 30
# Epoch: 5, Batch_idx: 102, Batch_size: 30
# Epoch: 5, Batch_idx: 103, Batch_size: 30
# Epoch: 5, Batch_idx: 104, Batch_size: 30
# Epoch: 5, Batch_idx: 105, Batch_size: 30
# Epoch: 5, Batch_idx: 106, Batch_size: 30
# Epoch: 5, Batch_idx: 107, Batch_size: 30
# Epoch: 5, Batch_idx: 108, Batch_size: 30
# Epoch: 5, Batch_idx: 109, Batch_size: 30
# Epoch: 5, Batch_idx: 110, Batch_size: 30
# Epoch: 5, Batch_idx: 111, Batch_size: 30
# Epoch: 5, Batch_idx: 112, Batch_size: 30
# Epoch: 5, Batch_idx: 113, Batch_size: 30
# Epoch: 5, Batch_idx: 114, Batch_size: 30
# Epoch: 5, Batch_idx: 115, Batch_size: 30
# Epoch: 5, Batch_idx: 116, Batch_size: 30
# Epoch: 5, Batch_idx: 117, Batch_size: 30
# Epoch: 5, Batch_idx: 118, Batch_size: 30
# Epoch: 5, Batch_idx: 119, Batch_size: 30
# Epoch: 5, Batch_idx: 120, Batch_size: 30
# Epoch: 5, Batch_idx: 121, Batch_size: 30
# Epoch: 5, Batch_idx: 122, Batch_size: 30
# Epoch: 5, Batch_idx: 123, Batch_size: 30
# Epoch: 5, Batch_idx: 124, Batch_size: 30
# Epoch: 5, Batch_idx: 125, Batch_size: 30
# Epoch: 5, Batch_idx: 126, Batch_size: 30
# Epoch: 5, Batch_idx: 127, Batch_size: 30
# Epoch: 5, Batch_idx: 128, Batch_size: 30
# Epoch: 5, Batch_idx: 129, Batch_size: 30
# Epoch: 5, Batch_idx: 130, Batch_size: 30
# Epoch: 5, Batch_idx: 131, Batch_size: 30
# Epoch: 5, Batch_idx: 132, Batch_size: 30
# Epoch: 5, Batch_idx: 133, Batch_size: 30
# Epoch: 5, Batch_idx: 134, Batch_size: 30
# Epoch: 5, Batch_idx: 135, Batch_size: 30
# Epoch: 5, Batch_idx: 136, Batch_size: 30
# Epoch: 5, Batch_idx: 137, Batch_size: 30
# Epoch: 5, Batch_idx: 138, Batch_size: 30
# Epoch: 5, Batch_idx: 139, Batch_size: 30
# Epoch: 5, Batch_idx: 140, Batch_size: 30
# Epoch: 5, Batch_idx: 141, Batch_size: 30
# Epoch: 5, Batch_idx: 142, Batch_size: 30
# Epoch: 5, Batch_idx: 143, Batch_size: 30
# Epoch: 5, Batch_idx: 144, Batch_size: 30
# Epoch: 5, Batch_idx: 145, Batch_size: 30
# Epoch: 5, Batch_idx: 146, Batch_size: 30
# Epoch: 5, Batch_idx: 147, Batch_size: 30
# Epoch: 5, Batch_idx: 148, Batch_size: 30
# Epoch: 5, Batch_idx: 149, Batch_size: 30
# Epoch: 5, Batch_idx: 150, Batch_size: 30
# Epoch: 5, Batch_idx: 151, Batch_size: 30
# Epoch: 5, Batch_idx: 152, Batch_size: 30
# Epoch: 5, Batch_idx: 153, Batch_size: 30
# Epoch: 5, Batch_idx: 154, Batch_size: 30
# Epoch: 5, Batch_idx: 155, Batch_size: 30
# Epoch: 5, Batch_idx: 156, Batch_size: 30
# Epoch: 5, Batch_idx: 157, Batch_size: 30
# Epoch: 5, Batch_idx: 158, Batch_size: 30
# Epoch: 5, Batch_idx: 159, Batch_size: 30
# Epoch: 5, Batch_idx: 160, Batch_size: 30
# Epoch: 5, Batch_idx: 161, Batch_size: 30
# Epoch: 5, Batch_idx: 162, Batch_size: 30
# Epoch: 5, Batch_idx: 163, Batch_size: 30
# Epoch: 5, Batch_idx: 164, Batch_size: 30
# Epoch: 5, Batch_idx: 165, Batch_size: 30
# Epoch: 5, Batch_idx: 166, Batch_size: 30
# Epoch: 5, Batch_idx: 167, Batch_size: 30
# Epoch: 5, Batch_idx: 168, Batch_size: 30
# Epoch: 5, Batch_idx: 169, Batch_size: 30
# Epoch: 5, Batch_idx: 170, Batch_size: 30
# Epoch: 5, Batch_idx: 171, Batch_size: 30
# Epoch: 5, Batch_idx: 172, Batch_size: 30
# Epoch: 5, Batch_idx: 173, Batch_size: 30
# Epoch: 5, Batch_idx: 174, Batch_size: 30
# Epoch: 5, Batch_idx: 175, Batch_size: 30
# Epoch: 5, Batch_idx: 176, Batch_size: 30
# Epoch: 5, Batch_idx: 177, Batch_size: 30
# Epoch: 5, Batch_idx: 178, Batch_size: 30
# Epoch: 5, Batch_idx: 179, Batch_size: 30
# Epoch: 5, Batch_idx: 180, Batch_size: 30
# Epoch: 5, Batch_idx: 181, Batch_size: 30
# Epoch: 5, Batch_idx: 182, Batch_size: 30
# Epoch: 5, Batch_idx: 183, Batch_size: 30
# Epoch: 5, Batch_idx: 184, Batch_size: 30
# Epoch: 5, Batch_idx: 185, Batch_size: 30
# Epoch: 5, Batch_idx: 186, Batch_size: 30
# Epoch: 5, Batch_idx: 187, Batch_size: 30
# Epoch: 5, Batch_idx: 188, Batch_size: 30
# Epoch: 5, Batch_idx: 189, Batch_size: 30
# Epoch: 5, Batch_idx: 190, Batch_size: 30
# Epoch: 5, Batch_idx: 191, Batch_size: 30
# Epoch: 5, Batch_idx: 192, Batch_size: 30
# Epoch: 5, Batch_idx: 193, Batch_size: 30
# Epoch: 5, Batch_idx: 194, Batch_size: 30
# Epoch: 5, Batch_idx: 195, Batch_size: 30
# Epoch: 5, Batch_idx: 196, Batch_size: 30
# Epoch: 5, Batch_idx: 197, Batch_size: 30
# Epoch: 5, Batch_idx: 198, Batch_size: 30
# Epoch: 5, Batch_idx: 199, Batch_size: 30
# Epoch: 5, Batch_idx: 200, Batch_size: 30
# Training set [6000/8993 (67%)] Loss: 2.003029
# Epoch: 5, Batch_idx: 201, Batch_size: 30
# Epoch: 5, Batch_idx: 202, Batch_size: 30
# Epoch: 5, Batch_idx: 203, Batch_size: 30
# Epoch: 5, Batch_idx: 204, Batch_size: 30
# Epoch: 5, Batch_idx: 205, Batch_size: 30
# Epoch: 5, Batch_idx: 206, Batch_size: 30
# Epoch: 5, Batch_idx: 207, Batch_size: 30
# Epoch: 5, Batch_idx: 208, Batch_size: 30
# Epoch: 5, Batch_idx: 209, Batch_size: 30
# Epoch: 5, Batch_idx: 210, Batch_size: 30
# Epoch: 5, Batch_idx: 211, Batch_size: 30
# Epoch: 5, Batch_idx: 212, Batch_size: 30
# Epoch: 5, Batch_idx: 213, Batch_size: 30
# Epoch: 5, Batch_idx: 214, Batch_size: 30
# Epoch: 5, Batch_idx: 215, Batch_size: 30
# Epoch: 5, Batch_idx: 216, Batch_size: 30
# Epoch: 5, Batch_idx: 217, Batch_size: 30
# Epoch: 5, Batch_idx: 218, Batch_size: 30
# Epoch: 5, Batch_idx: 219, Batch_size: 30
# Epoch: 5, Batch_idx: 220, Batch_size: 30
# Epoch: 5, Batch_idx: 221, Batch_size: 30
# Epoch: 5, Batch_idx: 222, Batch_size: 30
# Epoch: 5, Batch_idx: 223, Batch_size: 30
# Epoch: 5, Batch_idx: 224, Batch_size: 30
# Epoch: 5, Batch_idx: 225, Batch_size: 30
# Epoch: 5, Batch_idx: 226, Batch_size: 30
# Epoch: 5, Batch_idx: 227, Batch_size: 30
# Epoch: 5, Batch_idx: 228, Batch_size: 30
# Epoch: 5, Batch_idx: 229, Batch_size: 30
# Epoch: 5, Batch_idx: 230, Batch_size: 30
# Epoch: 5, Batch_idx: 231, Batch_size: 30
# Epoch: 5, Batch_idx: 232, Batch_size: 30
# Epoch: 5, Batch_idx: 233, Batch_size: 30
# Epoch: 5, Batch_idx: 234, Batch_size: 30
# Epoch: 5, Batch_idx: 235, Batch_size: 30
# Epoch: 5, Batch_idx: 236, Batch_size: 30
# Epoch: 5, Batch_idx: 237, Batch_size: 30
# Epoch: 5, Batch_idx: 238, Batch_size: 30
# Epoch: 5, Batch_idx: 239, Batch_size: 30
# Epoch: 5, Batch_idx: 240, Batch_size: 30
# Epoch: 5, Batch_idx: 241, Batch_size: 30
# Epoch: 5, Batch_idx: 242, Batch_size: 30
# Epoch: 5, Batch_idx: 243, Batch_size: 30
# Epoch: 5, Batch_idx: 244, Batch_size: 30
# Epoch: 5, Batch_idx: 245, Batch_size: 30
# Epoch: 5, Batch_idx: 246, Batch_size: 30
# Epoch: 5, Batch_idx: 247, Batch_size: 30
# Epoch: 5, Batch_idx: 248, Batch_size: 30
# Epoch: 5, Batch_idx: 249, Batch_size: 30
# Epoch: 5, Batch_idx: 250, Batch_size: 30
# Epoch: 5, Batch_idx: 251, Batch_size: 30
# Epoch: 5, Batch_idx: 252, Batch_size: 30
# Epoch: 5, Batch_idx: 253, Batch_size: 30
# Epoch: 5, Batch_idx: 254, Batch_size: 30
# Epoch: 5, Batch_idx: 255, Batch_size: 30
# Epoch: 5, Batch_idx: 256, Batch_size: 30
# Epoch: 5, Batch_idx: 257, Batch_size: 30
# Epoch: 5, Batch_idx: 258, Batch_size: 30
# Epoch: 5, Batch_idx: 259, Batch_size: 30
# Epoch: 5, Batch_idx: 260, Batch_size: 30
# Epoch: 5, Batch_idx: 261, Batch_size: 30
# Epoch: 5, Batch_idx: 262, Batch_size: 30
# Epoch: 5, Batch_idx: 263, Batch_size: 30
# Epoch: 5, Batch_idx: 264, Batch_size: 30
# Epoch: 5, Batch_idx: 265, Batch_size: 30
# Epoch: 5, Batch_idx: 266, Batch_size: 30
# Epoch: 5, Batch_idx: 267, Batch_size: 30
# Epoch: 5, Batch_idx: 268, Batch_size: 30
# Epoch: 5, Batch_idx: 269, Batch_size: 30
# Epoch: 5, Batch_idx: 270, Batch_size: 30
# Epoch: 5, Batch_idx: 271, Batch_size: 30
# Epoch: 5, Batch_idx: 272, Batch_size: 30
# Epoch: 5, Batch_idx: 273, Batch_size: 30
# Epoch: 5, Batch_idx: 274, Batch_size: 30
# Epoch: 5, Batch_idx: 275, Batch_size: 30
# Epoch: 5, Batch_idx: 276, Batch_size: 30
# Epoch: 5, Batch_idx: 277, Batch_size: 30
# Epoch: 5, Batch_idx: 278, Batch_size: 30
# Epoch: 5, Batch_idx: 279, Batch_size: 30
# Epoch: 5, Batch_idx: 280, Batch_size: 30
# Epoch: 5, Batch_idx: 281, Batch_size: 30
# Epoch: 5, Batch_idx: 282, Batch_size: 30
# Epoch: 5, Batch_idx: 283, Batch_size: 30
# Epoch: 5, Batch_idx: 284, Batch_size: 30
# Epoch: 5, Batch_idx: 285, Batch_size: 30
# Epoch: 5, Batch_idx: 286, Batch_size: 30
# Epoch: 5, Batch_idx: 287, Batch_size: 30
# Epoch: 5, Batch_idx: 288, Batch_size: 30
# Epoch: 5, Batch_idx: 289, Batch_size: 30
# Epoch: 5, Batch_idx: 290, Batch_size: 30
# Epoch: 5, Batch_idx: 291, Batch_size: 30
# Epoch: 5, Batch_idx: 292, Batch_size: 30
# Epoch: 5, Batch_idx: 293, Batch_size: 30
# Epoch: 5, Batch_idx: 294, Batch_size: 30
# Epoch: 5, Batch_idx: 295, Batch_size: 30
# Epoch: 5, Batch_idx: 296, Batch_size: 30
# Epoch: 5, Batch_idx: 297, Batch_size: 30
# Epoch: 5, Batch_idx: 298, Batch_size: 30
# Epoch: 5, Batch_idx: 299, Batch_size: 23
# 100%|██████████| 5/5 [10:08<00:00, 121.60s/it]
# {
#   "loss": 2.0422606080077417,
#   "acc": 2.0422606080077417,
#   "precision": 2.0422606080077417,
#   "recall": 2.0422606080077417,
#   "f": 2.0422606080077417
# }
# Metrics after epoch: 5: None
# Model saved in models/ResNet18/23-Jan-10-02-01.pt
# /Users/adamwojdyla/Documents/Studia/Magisterskie/AITech-flats/experiments/plots.py:70: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.
#   fig.legend(axis, labels=['test', 'train'], loc="lower center")
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 test_metrics, train_metrics = conduct_experiment("ResNet18", resnet_model, 5, torch.optim.Adam(resnet_model.parameters()))
#
# Cell In[7], line 18, in conduct_experiment(title, model, n_epochs, optimizer)
#      16 _, preds, _ = evaluate(model, test_loader, criterion, device)
#      17 labels = data_loader.get_label_names()
# ---> 18 plots.show_missclassified(test_loader.dataset, preds, labels)
#      20 return test_metrics, train_metrics
#
# File ~/Documents/Studia/Magisterskie/AITech-flats/experiments/plots.py:87, in show_missclassified(dataset, preds, label_names, count_per_class)
#      80 def show_missclassified(
#      81         dataset: Dataset,
#      82         preds: np.ndarray,
#      83         label_names: dict,
#      84         count_per_class: int = 5
#      85 ):
#      86     results = {}
# ---> 87     for i in label_names.keys():
#      88         results[i] = []
#      90     indexes = np.random.permutation(len(preds))
#
# AttributeError: 'list' object has no attribute 'keys'

# %%
import matplotlib.pyplot as plt
image=test_dataset.dataset[0][0]
plt.figure()
plt.imshow(transforms.ToPILImage()(image[:,:,:-1]))
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)
